# %%
library("datasets")
library("ggplot2")
library("gridExtra")

# %%
head(beaver2)
# Out:
#   day time temp  activ
# 1 307  930 36.58 0
# 2 307  940 36.73 0
# 3 307  950 36.93 0
# 4 307 1000 37.15 0
# 5 307 1010 37.23 0
# 6 307 1020 37.24 0

# %%
beaver2 = na.omit(beaver2)
dim(beaver2)
# Out:
# [1] 100   4

# %%
summary(beaver2)
# Out:
#       day             time           temp           activ
#  Min.   :307.0   Min.   :   0   Min.   :36.58   Min.   :0.00
#  1st Qu.:307.0   1st Qu.:1128   1st Qu.:37.15   1st Qu.:0.00
#  Median :307.0   Median :1535   Median :37.73   Median :1.00
#  Mean   :307.1   Mean   :1446   Mean   :37.60   Mean   :0.62
#  3rd Qu.:307.0   3rd Qu.:1942   3rd Qu.:37.98   3rd Qu.:1.00
#  Max.   :308.0   Max.   :2350   Max.   :38.35   Max.   :1.00

# %% [markdown]
# ### Merging duration data

# %%
beaver2$duration <- 2400*(beaver2$day - 307) + beaver2$time
summary(beaver2)
# Out:
#       day             time           temp           activ         duration
#  Min.   :307.0   Min.   :   0   Min.   :36.58   Min.   :0.00   Min.   : 930
#  1st Qu.:307.0   1st Qu.:1128   1st Qu.:37.15   1st Qu.:0.00   1st Qu.:1338
#  Median :307.0   Median :1535   Median :37.73   Median :1.00   Median :1745
#  Mean   :307.1   Mean   :1446   Mean   :37.60   Mean   :0.62   Mean   :1758
#  3rd Qu.:307.0   3rd Qu.:1942   3rd Qu.:37.98   3rd Qu.:1.00   3rd Qu.:2162
#  Max.   :308.0   Max.   :2350   Max.   :38.35   Max.   :1.00   Max.   :2600

# %% [markdown]
# ### Looking at data

# %%
plot(beaver2[, -which(names(beaver2) %in% c("time","day"))])
# Out:
# plot without title

# %%
p1 <- qplot(beaver2$day, geom="histogram") 
p2 <- qplot(beaver2$duration, geom="histogram") 
p3 <- qplot(beaver2$activ, geom="histogram") 


grid.arrange(p1, p2, p3, nrow = 2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ### Looking at correlations

# %%
ggplot(beaver2, aes(x=duration, y=duration, color=activ)) +
    geom_point() + 
    ggtitle('Duration Vs Temp')
# Out:
# plot without title
