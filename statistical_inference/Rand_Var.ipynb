# %%
# Out:
# Error in eval(expr, envir, enclos): object 'SMarket' not found
# Traceback:

# %% [markdown]
# Describes how extracurricular engagement (percentile of student on attendence of optional school activities) is affected by both student diligence and family income. While student diligence could increase the amount of optional school activities attended, family income is very likely a limiting factor. students with more financial restrictions would have priorities above optional school activities.
#
# Given the dilligence and family income of students, predict their extracurricular engagment level

# %%
dilligence <- rnorm(200,1,10) 
family_income <- rnbinom(200,10,.5)

academic_engagement <- 50 + 10*dilligence + (500*family_income) + rnorm(200,0,1000)

# %%
hist(dilligence)
# Out:
# Plot with title “Histogram of dilligence”

# %%
hist(family_income)
# Out:
# Plot with title “Histogram of family_income”

# %%
hist(academic_engagement)
# Out:
# Plot with title “Histogram of academic_engagement”

# %%
# see results
lm(academic_engagement ~ dilligence + family_income)
# Out:
# Call:
# lm(formula = academic_engagement ~ dilligence + family_income)
#
# Coefficients:
#   (Intercept)     dilligence  family_income
#       240.654          4.733        483.819

# %%
data <- data.frame(dilligence = dilligence, family_income = family_income,academic_engagement = academic_engagement)

# %%
dim(data)
dim(data[0:100,])
# Out:
# [1] 200   3
# [1] 100   3

# %%
write.csv(data[0:100,], file = "academicData_train.csv")
write.csv(data[100:200,], file = "academicData_test.csv")

# %%
t1 = runif(1000)

# %%
hist(t1)
# Out:
# Plot with title “Histogram of t1”

# %%
pred = 2.159*data$dilligence+521.022*data$family_income-231.585

rmse <- function(error)
{
    sqrt(mean(error^2))
}

rsq <- function (x, y) cor(x, y) ^ 2

paste('rmse: ',rmse(data$academic_engagement-pred))
paste('rsq: ',rsq(data$academic_engagement,pred))
# Out:
# [1] "rmse:  953.850799071139"
# [1] "rsq:  0.848000220091764"
