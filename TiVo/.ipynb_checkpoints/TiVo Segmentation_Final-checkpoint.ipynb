# %% [markdown]
# # TiVo Segmentation
#
# ### How to segment market?
# - What do people want?
#     - what features do they care about?
#     - how much storage do they need?
# - How can I reach them?
#     - can I communicate with them specifically?
# - How should it be priced?
#     - will early adopters spend a lot of money on it? what about late adopters?
#     - monthly fee vs lifetime fee?
#     - long term major rev source: data
#     - price for a model: 500
#
# ### Qs that might have been interesting
# - Their values/ identity
# - How they interact with TV service
#     - When they watch
#     - Who they watch with
#     - What type of things do they watch
# - Problems they currently have w TV service
#     - weird, they complained about timing and interruptions w tv but most people valued recording to watch w family?
# - How they feel about each feature
#     - timing control
#     - play and record
#     - option to skip commercial
#     - open access to programs
#     - search for and record shows
#     - auto record shows
#     - recommendations for shows
# - How much they'd be willing to pay for the product

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pandas.io.json import json_normalize
from datetime import datetime
from sklearn import preprocessing

# %%
# import and check data
df = pd.read_csv("TiVoData.csv")
df = df.drop(df.index[len(df)-1])
df = df.drop(df.index[len(df)-1])
df = df.drop(df.index[len(df)-1])
df.head()
# Out:
#     ID  Gender Marital Status   Work Status Education  \
# 0  1.0    male        married  professional      none
# 1  2.0    male         single          none      none
# 2  3.0    male        married  professional        BA
# 3  4.0    male        married          none       PhD
# 4  5.0  female         single          none      none
#
#    Annual Income (x1000 $)   Age       Location Purchasing Decision-maker  \
# 0                     49.0  30.0        Florida                    family
# 1                     46.0  36.0        Alabama                    single
# 2                     58.0  66.0  Massachusetts                    family
# 3                     51.0  78.0       New York                    family
# 4                     46.0  52.0        Montana                    single
#
#          Purchasing Location  Monthly Electronics Spend  \
# 0  mass-consumer electronics                       35.0
# 1  mass-consumer electronics                       35.0
# 2           specialty stores                       64.0
# 3  mass-consumer electronics                       33.0
# 4  mass-consumer electronics                       45.0
#
#    Monthly Household Spend  Purchasing Frequency (every x months)  \
# 0                    150.0                                   13.0
# 1                    163.0                                   26.0
# 2                    103.0                                   13.0
# 3                    154.0                                   22.0
# 4                    161.0                                   47.0
#
#   Technology Adoption  TV Viewing (hours/day)  \
# 0                late                     2.0
# 1                late                    10.0
# 2               early                     0.0
# 3                late                     5.0
# 4                late                     2.0
#
#                              Favorite feature
# 0  saving favorite shows to watch as a family
# 1  saving favorite shows to watch as a family
# 2                               time shifting
# 3  saving favorite shows to watch as a family
# 4  saving favorite shows to watch as a family

# %%
# convert string factors to type: category

dfE = pd.read_csv("TiVoData.csv")
dfE = dfE.drop(dfE.index[len(dfE)-1])
dfE = dfE.drop(dfE.index[len(dfE)-1])
dfE = dfE.drop(dfE.index[len(dfE)-1])
df.shape
dfE["Gender"] = dfE["Gender"].astype("category")
dfE["Marital Status"] = dfE["Marital Status"].astype("category")
dfE["Work Status"] = dfE["Work Status"].astype("category")
dfE["Education"] = dfE["Education"].astype("category")
dfE["Location"] = dfE["Location"].astype("category")
dfE["Purchasing Decision-maker"] = dfE["Purchasing Decision-maker"].astype("category")
dfE["Purchasing Location"] = dfE["Purchasing Location"].astype("category")
dfE["Technology Adoption"] = dfE["Technology Adoption"].astype("category")
dfE["Favorite feature"] = dfE["Favorite feature"].astype("category")
dfE.dtypes
# Out:
# ID                                        float64
# Gender                                   category
# Marital Status                           category
# Work Status                              category
# Education                                category
# Annual Income (x1000 $)                   float64
# Age                                       float64
# Location                                 category
# Purchasing Decision-maker                category
# Purchasing Location                      category
# Monthly Electronics Spend                 float64
# Monthly Household Spend                   float64
# Purchasing Frequency (every x months)     float64
# Technology Adoption                      category
# TV Viewing (hours/day)                    float64
# Favorite feature                         category
# dtype: object

# %%
list(dfE.columns.values)
# Out:
# ['ID',
#  'Gender',
#  'Marital Status',
#  'Work Status',
#  'Education',
#  'Annual Income (x1000 $)',
#  'Age',
#  'Location',
#  'Purchasing Decision-maker',
#  'Purchasing Location',
#  'Monthly Electronics Spend',
#  'Monthly Household Spend',
#  'Purchasing Frequency (every x months)',
#  'Technology Adoption',
#  'TV Viewing (hours/day)',
#  'Favorite feature']

# %%
# encode qualitative factors

dfE["Gender"] = dfE["Gender"].cat.codes
dfE["Marital Status"] = dfE["Marital Status"].cat.codes
dfE["Work Status"] = dfE["Work Status"].cat.codes
dfE["Education"] = dfE["Education"].cat.codes
dfE["Location"] = dfE["Location"].cat.codes
dfE["Purchasing Decision-maker"] = dfE["Purchasing Decision-maker"].cat.codes
dfE["Purchasing Location"] = dfE["Purchasing Location"].cat.codes
dfE["Technology Adoption"] = dfE["Technology Adoption"].cat.codes
dfE["Favorite feature"] = dfE["Favorite feature"].cat.codes
dfE.head()
# Out:
#     ID  Gender  Marital Status  Work Status  Education  \
# 0  1.0       1               0            1          3
# 1  2.0       1               1            0          3
# 2  3.0       1               0            1          0
# 3  4.0       1               0            0          2
# 4  5.0       0               1            0          3
#
#    Annual Income (x1000 $)   Age  Location  Purchasing Decision-maker  \
# 0                     49.0  30.0         8                          0
# 1                     46.0  36.0         0                          1
# 2                     58.0  66.0        20                          0
# 3                     51.0  78.0        31                          0
# 4                     46.0  52.0        25                          1
#
#    Purchasing Location  Monthly Electronics Spend  Monthly Household Spend  \
# 0                    1                       35.0                    150.0
# 1                    1                       35.0                    163.0
# 2                    3                       64.0                    103.0
# 3                    1                       33.0                    154.0
# 4                    1                       45.0                    161.0
#
#    Purchasing Frequency (every x months)  Technology Adoption  \
# 0                                   13.0                    1
# 1                                   26.0                    1
# 2                                   13.0                    0
# 3                                   22.0                    1
# 4                                   47.0                    1
#
#    TV Viewing (hours/day)  Favorite feature
# 0                     2.0                 2
# 1                    10.0                 2
# 2                     0.0                 4
# 3                     5.0                 2
# 4                     2.0                 2

# %%
# %matplotlib notebook
from itertools import combinations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(dfE.columns)//3, 3, figsize=(10, 15))

i = 0
for triaxis in axes:
    for axis in triaxis:
        dfE.hist(column = dfE.columns[i], ax=axis)
        i = i+1
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
from itertools import combinations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(dfE.columns)//3, 3, figsize=(10, 10))

i = 0
for triaxis in axes:
    for axis in triaxis:
        dfE.boxplot(column = dfE.columns[i], ax=axis)
        i = i+1
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# remove outliers in annual income

dfE[dfE["Annual Income (x1000 $)"] >500]

dfET = dfE.drop(dfE.index[440])
dfET = dfET.drop(dfET.index[921])

dfT = df.drop(df.index[440])
dfT = dfT.drop(dfT.index[921])

# %%
dfET.describe()
# Out:
#                 ID      Gender  Marital Status  Work Status   Education  \
# count   998.000000  998.000000      998.000000   998.000000  998.000000
# mean    500.136273    0.534068        0.280561     0.649299    1.862725
# std     288.792790    0.499088        0.449499     0.477429    1.284970
# min       1.000000    0.000000        0.000000     0.000000    0.000000
# 25%     250.250000    0.000000        0.000000     0.000000    0.000000
# 50%     500.500000    1.000000        0.000000     1.000000    3.000000
# 75%     749.750000    1.000000        1.000000     1.000000    3.000000
# max    1000.000000    1.000000        1.000000     1.000000    3.000000
#
#        Annual Income (x1000 $)         Age    Location  \
# count               998.000000  998.000000  998.000000
# mean                 37.712425   48.280561   21.685371
# std                  10.916500   17.826913   14.400045
# min                  21.000000   18.000000    0.000000
# 25%                  29.000000   32.000000    8.000000
# 50%                  32.500000   49.000000   19.000000
# 75%                  48.000000   63.000000   36.000000
# max                  64.000000   80.000000   49.000000
#
#        Purchasing Decision-maker  Purchasing Location  \
# count                 998.000000           998.000000
# mean                    0.440882             1.466934
# std                     0.496742             1.196957
# min                     0.000000             0.000000
# 25%                     0.000000             0.000000
# 50%                     0.000000             2.000000
# 75%                     1.000000             2.000000
# max                     1.000000             4.000000
#
#        Monthly Electronics Spend  Monthly Household Spend  \
# count                 998.000000               998.000000
# mean                   30.903808                94.167335
# std                    17.015680                67.219733
# min                     7.000000                10.000000
# 25%                    17.000000                47.000000
# 50%                    25.000000                73.000000
# 75%                    42.000000               123.750000
# max                    88.000000               390.000000
#
#        Purchasing Frequency (every x months)  Technology Adoption  \
# count                             998.000000           998.000000
# mean                               23.016032             0.200401
# std                                13.873831             0.400501
# min                                 1.000000             0.000000
# 25%                                11.000000             0.000000
# 50%                                22.000000             0.000000
# 75%                                35.000000             0.000000
# max                                48.000000             1.000000
#
#        TV Viewing (hours/day)  Favorite feature
# count              998.000000        998.000000
# mean                 2.371743          2.078156
# std                  2.912823          1.463670
# min                  0.000000          0.000000
# 25%                  1.000000          1.000000
# 50%                  1.000000          2.000000
# 75%                  2.000000          3.000000
# max                 14.000000          4.000000

# %%
corr = dfET.corr()**2
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col0 {
#             background-color:  #023858;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col9 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col10 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col11 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col12 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col13 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col14 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row0_col15 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col1 {
#             background-color:  #023858;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col2 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col3 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col5 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col6 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col7 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col8 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col9 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col10 {
#             background-color:  #fdf5fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col11 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col12 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col13 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col14 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row1_col15 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col2 {
#             background-color:  #023858;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col3 {
#             background-color:  #faf3f9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col5 {
#             background-color:  #fbf3f9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col6 {
#             background-color:  #f4eef6;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col7 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col8 {
#             background-color:  #dad9ea;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col9 {
#             background-color:  #fdf5fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col10 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col11 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col12 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col13 {
#             background-color:  #f9f2f8;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col14 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row2_col15 {
#             background-color:  #fcf4fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col2 {
#             background-color:  #faf3f9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col3 {
#             background-color:  #023858;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col4 {
#             background-color:  #f8f1f8;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col5 {
#             background-color:  #faf2f8;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col6 {
#             background-color:  #fcf4fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col7 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col8 {
#             background-color:  #fef6fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col9 {
#             background-color:  #f3edf5;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col10 {
#             background-color:  #f2ecf5;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col11 {
#             background-color:  #f7f0f7;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col12 {
#             background-color:  #fbf3f9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col13 {
#             background-color:  #fbf4f9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col14 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row3_col15 {
#             background-color:  #fdf5fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col3 {
#             background-color:  #f8f1f8;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col4 {
#             background-color:  #023858;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col5 {
#             background-color:  #e0deed;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col6 {
#             background-color:  #fdf5fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col7 {
#             background-color:  #fff7fb;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col8 {
#             background-color:  #fef6fa;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col9 {
#             background-color:  #f2ecf5;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col10 {
#             background-color:  #d6d6e9;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3row4_col11 {
#             background-color:  #eee9f3;
#         }    #T_746f75d4_dcd8_11e8_b6a8_8ba196ac8ff3r

# %% [markdown]
# ### Factors that can be eliminated (can be explained by another)
#
# Monthly Household Spend (approximated by Monthly Electronics Spend)
#
#
# Annual Income (approximated by Monthly Electronics Spend)
#
#
# TV Viewing (approsimated by Tech Adoption)

# %%
# i left tv viewing in just cause its an important var and i want to see it later

dfTx = dfT.drop(columns=["Monthly Household Spend", "Annual Income (x1000 $)"])
dfETx = dfET.drop(columns=["Monthly Household Spend", "Annual Income (x1000 $)"])

# %%
# %matplotlib notebook
from itertools import combinations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(dfETx.columns)//3, 3, figsize=(10, 10))

i = 0
for triaxis in axes:
    for axis in triaxis:
        dfETx.hist(column = dfETx.columns[i], bins = 100, ax=axis)
        i = i+1
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
from itertools import combinations
import matplotlib.pyplot as plt

fig, axes = plt.subplots(len(dfETx.columns)//3, 3, figsize=(10, 10))

i = 0
for triaxis in axes:
    for axis in triaxis:
        dfETx.boxplot(column = dfETx.columns[i], ax=axis)
        i = i+1
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Understanding Factors
# - monthly electronics/household spend has a few high spending outliers clustered together (right skew)
# - TV viewing also has a few high watching outliers
#
#
# *intersts: perhaps the outliers across these 2 factors are related?*

# %% [markdown]
# # Segmenting by Purchasing Location and TV Viewing

# %% [markdown]
# ### simplifying through similar groups

# %%
# discount and retail
discNRet = dfTx.loc[(dfTx["Purchasing Location"] == "discount") | (dfTx["Purchasing Location"] == "retail")]
discNRet.head()
# Out:
#       ID  Gender Marital Status   Work Status Education   Age       Location  \
# 5    6.0  female        married          none        BA  72.0     New Jersey
# 6    7.0    male        married  professional      none  62.0     California
# 7    8.0    male        married          none      none  30.0  New Hampshire
# 9   10.0  female        married  professional      none  59.0          Idaho
# 10  11.0  female         single  professional       PhD  25.0        Florida
#
#    Purchasing Decision-maker Purchasing Location  Monthly Electronics Spend  \
# 5                     single              retail                       14.0
# 6                     single            discount                       18.0
# 7                     single              retail                       23.0
# 9                     family            discount                       16.0
# 10                    single            discount                       38.0
#
#     Purchasing Frequency (every x months) Technology Adoption  \
# 5                                    32.0               early
# 6                                    41.0               early
# 7                                     9.0               early
# 9                                    25.0               early
# 10                                    2.0               early
#
#     TV Viewing (hours/day)                  Favorite feature
# 5                      1.0                     time shifting
# 6                      0.0                       cool gadget
# 7                      1.0                  schedule control
# 9                      0.0                  schedule control
# 10                     6.0  programming/interactive features

# %%
sns.pairplot(discNRet.loc[:, discNRet.columns != 'ID'],hue = "Purchasing Location")
sns.pairplot(discNRet.loc[:, discNRet.columns != 'ID'],hue = "Favorite feature")
# Out:
# <img src="data:image/png;base64,..." width="1150.8">
# <img src="data:image/png;base64,..." width="1286">

# %%
# cool gadget, schedule control, time shifting

coolT = dfTx.loc[(dfTx["Favorite feature"] == "cool gadget") | (dfTx["Favorite feature"] == "schedule control") | (dfTx["Favorite feature"] == "time shifting")]
coolT.head()
# Out:
#     ID  Gender Marital Status   Work Status Education   Age       Location  \
# 2  3.0    male        married  professional        BA  66.0  Massachusetts
# 5  6.0  female        married          none        BA  72.0     New Jersey
# 6  7.0    male        married  professional      none  62.0     California
# 7  8.0    male        married          none      none  30.0  New Hampshire
# 8  9.0    male        married  professional      none  60.0  Massachusetts
#
#   Purchasing Decision-maker Purchasing Location  Monthly Electronics Spend  \
# 2                    family    specialty stores                       64.0
# 5                    single              retail                       14.0
# 6                    single            discount                       18.0
# 7                    single              retail                       23.0
# 8                    family    specialty stores                       74.0
#
#    Purchasing Frequency (every x months) Technology Adoption  \
# 2                                   13.0               early
# 5                                   32.0               early
# 6                                   41.0               early
# 7                                    9.0               early
# 8                                    1.0               early
#
#    TV Viewing (hours/day)  Favorite feature
# 2                     0.0     time shifting
# 5                     1.0     time shifting
# 6                     0.0       cool gadget
# 7                     1.0  schedule control
# 8                     0.0  schedule control

# %%
sns.pairplot(coolT.loc[:, coolT.columns != 'ID'],hue = "Favorite feature")
sns.pairplot(coolT.loc[:, coolT.columns != 'ID'],hue = "Purchasing Location")
# Out:
# <img src="data:image/png;base64,..." width="1164">
# <img src="data:image/png;base64,..." width="1158.8">

# %%
dfTx.head()
# Out:
#     ID  Gender Marital Status   Work Status Education   Age       Location  \
# 0  1.0    male        married  professional      none  30.0        Florida
# 1  2.0    male         single          none      none  36.0        Alabama
# 2  3.0    male        married  professional        BA  66.0  Massachusetts
# 3  4.0    male        married          none       PhD  78.0       New York
# 4  5.0  female         single          none      none  52.0        Montana
#
#   Purchasing Decision-maker        Purchasing Location  \
# 0                    family  mass-consumer electronics
# 1                    single  mass-consumer electronics
# 2                    family           specialty stores
# 3                    family  mass-consumer electronics
# 4                    single  mass-consumer electronics
#
#    Monthly Electronics Spend  Purchasing Frequency (every x months)  \
# 0                       35.0                                   13.0
# 1                       35.0                                   26.0
# 2                       64.0                                   13.0
# 3                       33.0                                   22.0
# 4                       45.0                                   47.0
#
#   Technology Adoption  TV Viewing (hours/day)  \
# 0                late                     2.0
# 1                late                    10.0
# 2               early                     0.0
# 3                late                     5.0
# 4                late                     2.0
#
#                              Favorite feature
# 0  saving favorite shows to watch as a family
# 1  saving favorite shows to watch as a family
# 2                               time shifting
# 3  saving favorite shows to watch as a family
# 4  saving favorite shows to watch as a family

# %%
### cleaning up the dataframe 
dfSimplified = dfTx.copy()
# by disc = retail
dfSimplified = dfSimplified.replace("retail", "discount & retail")
dfSimplified = dfSimplified.replace("discount", "discount & retail")


# by cool gadget = schedule control = time shifting
dfSimplified = dfSimplified.replace("cool gadget", "timing control")
dfSimplified = dfSimplified.replace("time shifting", "timing control")
dfSimplified = dfSimplified.replace("schedule control", "timing control")
dfSimplified.head(20)
# Out:
#       ID  Gender Marital Status   Work Status Education   Age       Location  \
# 0    1.0    male        married  professional      none  30.0        Florida
# 1    2.0    male         single          none      none  36.0        Alabama
# 2    3.0    male        married  professional        BA  66.0  Massachusetts
# 3    4.0    male        married          none       PhD  78.0       New York
# 4    5.0  female         single          none      none  52.0        Montana
# 5    6.0  female        married          none        BA  72.0     New Jersey
# 6    7.0    male        married  professional      none  62.0     California
# 7    8.0    male        married          none      none  30.0  New Hampshire
# 8    9.0    male        married  professional      none  60.0  Massachusetts
# 9   10.0  female        married  professional      none  59.0          Idaho
# 10  11.0  female         single  professional       PhD  25.0        Florida
# 11  12.0  female        married          none      none  57.0        Florida
# 12  13.0    male        married  professional        BA  80.0     New Jersey
# 13  14.0  female        married          none      none  36.0         Nevada
# 14  15.0    male         single  professional      none  61.0     California
# 15  16.0  female        married  professional      none  54.0       Illinois
# 16  17.0    male        married  professional        BA  58.0          Idaho
# 17  18.0  female        married  professional      none  30.0          Maine
# 18  19.0  female         single  professional       PhD  25.0         Alaska
# 19  20.0  female        married  professional      none  58.0   South Dakota
#
#    Purchasing Decision-maker        Purchasing Location  \
# 0                     family  mass-consumer electronics
# 1                     single  mass-consumer electronics
# 2                     family           specialty stores
# 3                     family  mass-consumer electronics
# 4                     single  mass-consumer electronics
# 5                     single          discount & retail
# 6                     single          discount & retail
# 7                     single          discount & retail
# 8                     family           specialty stores
# 9                     family          discount & retail
# 10                    single          discount & retail
# 11                    family  mass-consumer electronics
# 12                    family           specialty stores
# 13                    single          discount & retail
# 14                    family          discount & retail
# 15                    family          discount & retail
# 16                    single          discount & retail
# 17                    family          discount & retail
# 18                    single          discount & retail
# 19                    family          discount & retail
#
#     Monthly Electronics Spend  Purchasing Frequency (every x months)  \
# 0                        35.0                                   13.0
# 1                        35.0                                   26.0
# 2                        64.0                                   13.0
# 3                        33.0                                   22.0
# 4                        45.0                                   47.0
# 5                        14.0                                   32.0
# 6                        18.0                                   41.0
# 7                        23.0                                    9.0
# 8                        74.0                                    1.0
# 9                        16.0                                   25.0
# 10                       38.0                                    2.0
# 11                       46.0                                   20.0
# 12                       53.0                                   10.0
# 13                       16.0                                    8.0
# 14                       14.0                                   39.0
# 15                       14.0                                   16.0
# 16                       16.0                                   14.0
# 17                       14.0                                    8.0
# 18                       24.0                                   11.0
# 19                       17.0                                   16.0
#
#    Technology Adoption  TV Viewing (hours/day)  \
# 0                 late                     2.0
# 1                 late                    10.0
# 2                early                     0.0
# 3                 late                     5.0
# 4                 late                     2.0
# 5                early                     1.0
# 6                early                     0.0
# 7                early                     1.0
# 8                early                     0.0
# 9                early                     0.0
# 10               early                     6.0
# 11                late                     5.0
# 12               early                     1.0
# 13               early                     2.0
# 14               early                     1.0
# 15               early                     0.0
# 16               early                     1.0
# 17               early                     2.0
# 18               early                     5.0
# 19               early                     0.0
#
#                               Favorite feature
# 0   saving favorite shows to watch as a family
# 1   saving favorite shows to watch as a family
# 2                               timing control
# 3   saving favorite shows to watch as a family
# 4   saving favorite shows to watch as a family
# 5                               timing control
# 6                               timing control
# 7                               timing control
# 8                               timing control
# 9                               timing control
# 10            programming/interactive features
# 11  saving favorite shows to watch as a family
# 12                              timing control
# 13                              timing control
# 14                              timing control
# 15                              timing control
# 16                              timing control
# 17                              timing control
# 18            programming/interactive features
# 19                              timing control

# %% [markdown]
# # Final Segmentation

# %%
# mass consumer
s1= dfSimplified.loc[(dfSimplified["Purchasing Location"] == "mass-consumer electronics")]
s2= dfSimplified.loc[(dfSimplified["Purchasing Location"] == "discount & retail") & (dfSimplified["Monthly Electronics Spend"] <= 26)]
s3= dfSimplified.loc[(dfSimplified["Purchasing Location"] == "discount & retail") & (dfSimplified["Monthly Electronics Spend"] > 26)]
s4= dfSimplified.loc[(dfSimplified["Purchasing Location"] == "specialty stores")]
s5= dfSimplified.loc[(dfSimplified["Purchasing Location"] == "web (ebay)")]

# %%
# summary of segments

print("S1: MASS CONSUMER ELECTRONICS")
print("MARKET SIZE: ",round(len(s1)/len(dfSimplified), 2))
print("MOST APPEALING FEATURE: ")
print("     ", s1["Favorite feature"].value_counts()/len(s1))
print("MONTHLY ELECTRONICS SPEND: ", round(s1["Monthly Electronics Spend"].mean(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s1["Technology Adoption"].value_counts()/len(s1))
print("TV VIEWING: ", round(s1["TV Viewing (hours/day)"].mean(),2))

print("______________")

print("S2: disc/ ret and low")
print("MARKET SIZE: ",round(len(s2)/len(dfSimplified), 2))
print("MOST APPEALING FEATURE: ")
print("     ", s2["Favorite feature"].value_counts()/len(s2))
print("MONTHLY ELECTRONICS SPEND: ", round(s2["Monthly Electronics Spend"].mean(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s2["Technology Adoption"].value_counts()/len(s2))
print("TV VIEWING: ", round(s2["TV Viewing (hours/day)"].mean(),2))

print("______________")

print("S3: disc/ ret and high")
print("MARKET SIZE: ",round(len(s3)/len(dfSimplified), 2))
print("MOST APPEALING FEATURE: ")
print("     ", s3["Favorite feature"].value_counts()/len(s3))
print("MONTHLY ELECTRONICS SPEND: ", round(s3["Monthly Electronics Spend"].mean(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s3["Technology Adoption"].value_counts()/len(s3))
print("TV VIEWING: ", round(s3["TV Viewing (hours/day)"].mean(),2))

print("______________")

print("S4: SPECIALTY")
print("MARKET SIZE: ",round(len(s4)/len(dfSimplified), 2))
print("MOST APPEALING FEATURE: ")
print("     ", s4["Favorite feature"].value_counts()/len(s4))
print("MONTHLY ELECTRONICS SPEND: ", round(s4["Monthly Electronics Spend"].mean(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s4["Technology Adoption"].value_counts()/len(s4))
print("TV VIEWING: ", round(s4["TV Viewing (hours/day)"].mean(),2))

print("______________")

print("S5: WEB (EBAY)")
print("MARKET SIZE: ",round(len(s5)/len(dfSimplified), 2))
print("MOST APPEALING FEATURE: ")
print("     ", s5["Favorite feature"].value_counts()/len(s5))
print("MONTHLY ELECTRONICS SPEND: ", round(s5["Monthly Electronics Spend"].mean(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s5["Technology Adoption"].value_counts()/len(s5))
print("TV VIEWING: ", round(s5["TV Viewing (hours/day)"].mean(),2))

print("______________")
# Out:
# S1: MASS CONSUMER ELECTRONICS
# MARKET SIZE:  0.2
# MOST APPEALING FEATURE:
#       saving favorite shows to watch as a family    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  41.4
# TECHNOLOGY ADOPTION:
#       late    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  6.32
# ______________
# S2: disc/ ret and low
# MARKET SIZE:  0.5
# MOST APPEALING FEATURE:
#       timing control                      0.996
# programming/interactive features    0.004
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  16.89
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  1.03
# ______________
# S3: disc/ ret and high
# MARKET SIZE:  0.09
# MOST APPEALING FEATURE:
#       programming/interactive features    0.977011
# timing control                      0.022989
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  33.11
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  3.0
# ______________
# S4: SPECIALTY
# MARKET SIZE:  0.17
# MOST APPEALING FEATURE:
#       timing control    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  58.28
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  1.11
# ______________
# S5: WEB (EBAY)
# MARKET SIZE:  0.04
# MOST APPEALING FEATURE:
#       programming/interactive features    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  33.58
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  3.23
# ______________

# %%
# homogeneity of segments

print("S1: MASS CONSUMER ELECTRONICS")
print("MOST APPEALING FEATURE: ")
print("     ", s1["Favorite feature"].value_counts()/len(s1))
print("MONTHLY ELECTRONICS SPEND: ", round(s1["Monthly Electronics Spend"].std(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s1["Technology Adoption"].value_counts()/len(s1))
print("TV VIEWING: ", round(s1["TV Viewing (hours/day)"].std(),2))

print("______________")

print("S2: disc/ ret and low")
print("MOST APPEALING FEATURE: ")
print("     ", s2["Favorite feature"].value_counts()/len(s2))
print("MONTHLY ELECTRONICS SPEND: ", round(s2["Monthly Electronics Spend"].std(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s2["Technology Adoption"].value_counts()/len(s2))
print("TV VIEWING: ", round(s2["TV Viewing (hours/day)"].std(),2))

print("______________")

print("S3: disc/ ret and high")
print("MOST APPEALING FEATURE: ")
print("     ", s3["Favorite feature"].value_counts()/len(s3))
print("MONTHLY ELECTRONICS SPEND: ", round(s3["Monthly Electronics Spend"].std(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s3["Technology Adoption"].value_counts()/len(s3))
print("TV VIEWING: ", round(s3["TV Viewing (hours/day)"].std(),2))

print("______________")

print("S4: SPECIALTY")
print("MOST APPEALING FEATURE: ")
print("     ", s4["Favorite feature"].value_counts()/len(s4))
print("MONTHLY ELECTRONICS SPEND: ", round(s4["Monthly Electronics Spend"].std(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s4["Technology Adoption"].value_counts()/len(s4))
print("TV VIEWING: ", round(s4["TV Viewing (hours/day)"].std(),2))

print("______________")

print("S5: WEB (EBAY)")
print("MOST APPEALING FEATURE: ")
print("     ", s5["Favorite feature"].value_counts()/len(s5))
print("MONTHLY ELECTRONICS SPEND: ", round(s5["Monthly Electronics Spend"].std(),2))
print("TECHNOLOGY ADOPTION: ")
print("     ", s5["Technology Adoption"].value_counts()/len(s5))
print("TV VIEWING: ", round(s5["TV Viewing (hours/day)"].std(),2))

print("______________")
# Out:
# S1: MASS CONSUMER ELECTRONICS
# MOST APPEALING FEATURE:
#       saving favorite shows to watch as a family    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  5.61
# TECHNOLOGY ADOPTION:
#       late    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  4.1
# ______________
# S2: disc/ ret and low
# MOST APPEALING FEATURE:
#       timing control                      0.996
# programming/interactive features    0.004
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  3.08
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  0.74
# ______________
# S3: disc/ ret and high
# MOST APPEALING FEATURE:
#       programming/interactive features    0.977011
# timing control                      0.022989
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  3.07
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  1.77
# ______________
# S4: SPECIALTY
# MOST APPEALING FEATURE:
#       timing control    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  13.32
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  0.68
# ______________
# S5: WEB (EBAY)
# MOST APPEALING FEATURE:
#       programming/interactive features    1.0
# Name: Favorite feature, dtype: float64
# MONTHLY ELECTRONICS SPEND:  2.91
# TECHNOLOGY ADOPTION:
#       early    1.0
# Name: Technology Adoption, dtype: float64
# TV VIEWING:  1.81
# ______________

# %%
# s4
# %matplotlib inline

print(s4["Monthly Electronics Spend"].describe())
sns.distplot(s4["Monthly Electronics Spend"])
plt.text(85,0.03,"mean: 58.28")
plt.text(85,0.028,"std: 13.32")
# Out:
# count    168.000000
# mean      58.279762
# std       13.319171
# min       23.000000
# 25%       49.000000
# 50%       59.000000
# 75%       67.000000
# max       88.000000
# Name: Monthly Electronics Spend, dtype: float64
# Text(85,0.028,'std: 13.32')
