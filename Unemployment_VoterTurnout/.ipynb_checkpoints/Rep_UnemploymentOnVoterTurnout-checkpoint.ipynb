# %% [markdown]
# # Load Data

# %%
require(readstata13)
require(foreign)
require(multiwayvcov)
require(mlogit)
require(xtable)
require(stargazer)
require(ggplot2)
require(car)
require(mgcv)
require(reshape2)
require(nnet)
library('Matching')

#Load in replication data from B&W
county.data <- read.dta13("BW JOP county replication data.dta")
indiv.data <- read.dta("BW JOP individual replication data.dta")
state.data <- read.dta("BW JOP state replication data.dta")
# Out:
# Loading required package: readstata13
# Loading required package: foreign
# Loading required package: multiwayvcov
# Loading required package: mlogit
# Loading required package: Formula
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: lmtest
# Loading required package: xtable
# Loading required package: stargazer
#
# Please cite as:
#
#  Hlavac, Marek (2018). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#  R package version 5.2.2. https://CRAN.R-project.org/package=stargazer
#
# Loading required package: ggplot2
# Loading required package: car
# Loading required package: carData
# Loading required package: mgcv
# Loading required package: nlme
# This is mgcv 1.8-27. For overview type 'help("mgcv-package")'.
# Loading required package: reshape2
# Loading required package: nnet
#
# Attaching package: ‘nnet’
#
# The following object is masked from ‘package:mgcv’:
#
#     multinom

# %% [markdown]
# # Replicating Table

# %% [markdown]
# ### No Year Fixed Effects

# %%
###############################################################################################  
#TABLE 4

state.data.t4 <- state.data[ which(state.data$presyear==0 
                                   & state.data$year >= '1980'
                                   & state.data$GubElection == 1), ]

#The regression they ran, without year fixed effects
table4.1 <- lm(vep ~ uerate + incparty + uerate*incparty + s_black + college + SenElection
               + factor(fips_state), data=state.data.t4)
summary(table4.1)
# Out:
# Call:
# lm(formula = vep ~ uerate + incparty + uerate * incparty + s_black +
#     college + SenElection + factor(fips_state), data = state.data.t4)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121557 -0.018952 -0.000036  0.018290  0.092344
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)           0.105935   0.082429   1.285 0.199957
# uerate                0.057951   0.159455   0.363 0.716600
# incpartyR            -0.043711   0.012992  -3.364 0.000891 ***
# s_black               1.112003   0.346261   3.211 0.001499 **
# college               0.043146   0.054991   0.785 0.433451
# SenElection           0.013849   0.004497   3.080 0.002311 **
# factor(fips_state)2   0.367554   0.080955   4.540 8.85e-06 ***
# factor(fips_state)4   0.215977   0.081569   2.648 0.008632 **
# factor(fips_state)5   0.107105   0.037167   2.882 0.004309 **
# factor(fips_state)6   0.221354   0.069422   3.189 0.001618 **
# factor(fips_state)8   0.281948   0.081764   3.448 0.000665 ***
# factor(fips_state)9   0.243874   0.066266   3.680 0.000287 ***
# factor(fips_state)12  0.124594   0.044493   2.800 0.005516 **
# factor(fips_state)13 -0.107580   0.018842  -5.710 3.29e-08 ***
# factor(fips_state)15  0.298144   0.085731   3.478 0.000599 ***
# factor(fips_state)16  0.353654   0.089966   3.931 0.000110 ***
# factor(fips_state)17  0.117089   0.043990   2.662 0.008292 **
# factor(fips_state)19  0.336904   0.084756   3.975 9.28e-05 ***
# factor(fips_state)20  0.251937   0.073429   3.431 0.000706 ***
# factor(fips_state)23  0.419018   0.089426   4.686 4.65e-06 ***
# factor(fips_state)24  0.002576   0.018869   0.137 0.891516
# factor(fips_state)25  0.296880   0.078207   3.796 0.000186 ***
# factor(fips_state)26  0.156968   0.046797   3.354 0.000923 ***
# factor(fips_state)27  0.423546   0.084606   5.006 1.07e-06 ***
# factor(fips_state)31  0.313071   0.078782   3.974 9.33e-05 ***
# factor(fips_state)32  0.171787   0.068024   2.525 0.012194 *
# factor(fips_state)33  0.266819   0.090559   2.946 0.003528 **
# factor(fips_state)35  0.267480   0.085638   3.123 0.002005 **
# factor(fips_state)36  0.081196   0.043092   1.884 0.060724 .
# factor(fips_state)39  0.183753   0.055414   3.316 0.001053 **
# factor(fips_state)40  0.186855   0.066484   2.811 0.005349 **
# factor(fips_state)41  0.374350   0.087555   4.276 2.74e-05 ***
# factor(fips_state)42  0.158736   0.059628   2.662 0.008284 **
# factor(fips_state)44  0.303830   0.079506   3.821 0.000169 ***
# factor(fips_state)45 -0.109844   0.022033  -4.985 1.18e-06 ***
# factor(fips_state)46  0.450199   0.089049   5.056 8.45e-07 ***
# factor(fips_state)47  0.036320   0.037639   0.965 0.335517
# factor(fips_state)48  0.074651   0.052418   1.424 0.155683
# factor(fips_state)50  0.368437   0.090977   4.050 6.90e-05 ***
# factor(fips_state)55  0.284988   0.075159   3.792 0.000189 ***
# factor(fips_state)56  0.378271   0.088267   4.286 2.63e-05 ***
# uerate:incpartyR      0.584038   0.191334   3.052 0.002522 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03471 on 243 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.8006,	Adjusted R-squared:  0.767
# F-statistic:  23.8 on 41 and 243 DF,  p-value: < 2.2e-16

# %% [markdown]
# # With Year Fixed Effects

# %%
#Re-calculate Table 4 regression with year fixed effects
table4 <- lm(vep ~ uerate + incparty + uerate*incparty + s_black + college + SenElection
             + factor(fips_state) + factor(year), data=state.data.t4)
summary(table4)
# Out:
# Call:
# lm(formula = vep ~ uerate + incparty + uerate * incparty + s_black +
#     college + SenElection + factor(fips_state) + factor(year),
#     data = state.data.t4)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121760 -0.017739 -0.001529  0.015975  0.094655
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           3.824e-02  8.238e-02   0.464 0.642911
# uerate                4.475e-01  2.185e-01   2.048 0.041665 *
# incpartyR            -3.815e-02  1.249e-02  -3.055 0.002513 **
# s_black               1.217e+00  3.318e-01   3.668 0.000302 ***
# college               1.756e-01  1.249e-01   1.406 0.161145
# SenElection           1.553e-02  4.295e-03   3.617 0.000365 ***
# factor(fips_state)2   3.792e-01  7.754e-02   4.890 1.86e-06 ***
# factor(fips_state)4   2.354e-01  7.816e-02   3.012 0.002876 **
# factor(fips_state)5   1.219e-01  3.577e-02   3.408 0.000769 ***
# factor(fips_state)6   2.279e-01  6.686e-02   3.409 0.000768 ***
# factor(fips_state)8   2.909e-01  7.938e-02   3.664 0.000306 ***
# factor(fips_state)9   2.524e-01  6.482e-02   3.893 0.000129 ***
# factor(fips_state)12  1.323e-01  4.273e-02   3.097 0.002194 **
# factor(fips_state)13 -1.112e-01  1.885e-02  -5.898 1.26e-08 ***
# factor(fips_state)15  3.210e-01  8.259e-02   3.887 0.000132 ***
# factor(fips_state)16  3.791e-01  8.617e-02   4.400 1.64e-05 ***
# factor(fips_state)17  1.185e-01  4.278e-02   2.770 0.006049 **
# factor(fips_state)19  3.645e-01  8.138e-02   4.479 1.17e-05 ***
# factor(fips_state)20  2.693e-01  7.077e-02   3.806 0.000180 ***
# factor(fips_state)23  4.445e-01  8.575e-02   5.184 4.66e-07 ***
# factor(fips_state)24 -7.005e-03  2.303e-02  -0.304 0.761207
# factor(fips_state)25  3.045e-01  7.608e-02   4.003 8.38e-05 ***
# factor(fips_state)26  1.597e-01  4.475e-02   3.568 0.000436 ***
# factor(fips_state)27  4.439e-01  8.155e-02   5.444 1.31e-07 ***
# factor(fips_state)31  3.420e-01  7.595e-02   4.502 1.06e-05 ***
# factor(fips_state)32  1.915e-01  6.511e-02   2.941 0.003601 **
# factor(fips_state)33  2.890e-01  8.731e-02   3.310 0.001077 **
# factor(fips_state)35  2.862e-01  8.198e-02   3.492 0.000573 ***
# factor(fips_state)36  8.286e-02  4.215e-02   1.966 0.050476 .
# factor(fips_state)39  1.950e-01  5.303e-02   3.678 0.000292 ***
# factor(fips_state)40  2.077e-01  6.376e-02   3.257 0.001291 **
# factor(fips_state)41  3.891e-01  8.387e-02   4.639 5.80e-06 ***
# factor(fips_state)42  1.733e-01  5.711e-02   3.034 0.002680 **
# factor(fips_state)44  3.197e-01  7.631e-02   4.190 3.95e-05 ***
# factor(fips_state)45 -1.150e-01  2.115e-02  -5.435 1.37e-07 ***
# factor(fips_state)46  4.834e-01  8.570e-02   5.641 4.82e-08 ***
# factor(fips_state)47  4.638e-02  3.600e-02   1.288 0.198905
# factor(fips_state)48  8.496e-02  5.036e-02   1.687 0.092882 .
# factor(fips_state)50  3.923e-01  8.761e-02   4.478 1.17e-05 ***
# factor(fips_state)55  3.045e-01  7.213e-02   4.222 3.46e-05 ***
# factor(fips_state)56  4.060e-01  8.463e-02   4.798 2.85e-06 ***
# factor(year)1986     -1.308e-02  8.935e-03  -1.463 0.144716
# factor(year)1990     -2.481e-03  1.071e-02  -0.232 0.817027
# factor(year)1994      5.686e-03  1.307e-02   0.435 0.663927
# factor(year)1998     -1.643e-02  1.606e-02  -1.023 0.307328
# factor(year)2002     -1.064e-02  1.654e-02  -0.643 0.520685
# factor(year)2006     -6.894e-05  1.908e-02  -0.004 0.997120
# factor(year)2010     -4.131e-02  1.601e-02  -2.579 0.010504 *
# uerate:incpartyR      4.709e-01  1.840e-01   2.559 0.011119 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03301 on 236 degrees of freedom
#   (4 observations deleted due to missingness)
# Multiple R-squared:  0.8249,	Adjusted R-squared:  0.7893
# F-statistic: 23.16 on 48 and 236 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Takeaways
# They did not control for Year even though they stated that they did
# Once you control for Year, every coefficient goes to 0 (minimal effect).

# %% [markdown]
# ### Extension: Gen Matching

# %%
# get quantiles on enemployment
ue_q = quantile(state.data.t4$uerate,c(.25,.75))

# make new dataset w control  beng <= 25% unemployment control 
# and treat being >= 75% unemployment
state.data.t4.match = state.data.t4[state.data.t4$uerate <= ue_q[1] | state.data.t4$uerate >= ue_q[2],]
state.data.t4.match$treat = ifelse(state.data.t4.match$uerate >= ue_q[2], 1, 0)

# %%
# remove NAs
state.data.t4.match <- state.data.t4.match[complete.cases(state.data.t4.match), ]
which(is.na(state.data.t4.match) == TRUE)
# Out:
# integer(0)

# %%
# Gen Match
library('Matching')
library('rgenoud')

Tr = state.data.t4.match$treat

X = cbind(state.data.t4.match$incparty, 
          state.data.t4.match$s_black, state.data.t4.match$college, 
          state.data.t4.match$SenElection, factor(state.data.t4.match$fips_state),
          factor(state.data.t4.match$year))


# X = cbind(state.data.t4.match$year,state.data.t4.match$fips_state,
#       state.data.t4.match$s_black, state.data.t4.match$SenElection,
#       state.data.t4.match$presyear, state.data.t4.match$college,
#       state.data.t4.match$college_diff, state.data.t4.match$pci_0000,
#       state.data.t4.match$prior_ue, state.data.t4.match$partyspending,
#       state.data.t4.match$priorue_diff, state.data.t4.match$spending_diff,
#       state.data.t4.match$share_open, state.data.t4.match$share_qual_out2,
#       state.data.t4.match$open_all_share, state.data.t4.match$quality_share_new,
#       state.data.t4.match$outparty_spend, state.data.t4.match$share_open_diff,
#       state.data.t4.match$open_all_share_diff, state.data.t4.match$share_qual_out2_diff,
#       state.data.t4.match$quality_share_diff, state.data.t4.match$outparty_spend_diff,
#       state.data.t4.match$s_black_diff, state.data.t4.match$pci0000_diff,
#       state.data.t4.match$senelec_diff, state.data.t4.match$incparty,
#       state.data.t4.match$GubElection, state.data.t4.match$vep,
#       state.data.t4.match$uerate)

genout1 = GenMatch(Tr = Tr, X = X,pop.size=200,max.generations=25)
mout1 = Match(Tr = Tr, X = X, Weight.matrix=genout1)
summary(mout1)
# Out:
# ##  rgenoud (Version 5.8-3.0, Build Date: 2019-01-22)
# ##  See http://sekhon.berkeley.edu/rgenoud for additional documentation.
# ##  Please cite software as:
# ##   Walter Mebane, Jr. and Jasjeet S. Sekhon. 2011.
# ##   ``Genetic Optimization Using Derivatives: The rgenoud package for R.''
# ##   Journal of Statistical Software, 42(11): 1-26.
# ##
# Tue Apr 23 17:13:32 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	22
# 	(2) Uniform Mutation.................. 	25
# 	(3) Boundary Mutation................. 	25
# 	(4) Non-Uniform Mutation.............. 	25
# 	(5) Polytope Crossover................ 	25
# 	(6) Simple Crossover.................. 	26
# 	(7) Whole Non-Uniform Mutation........ 	25
# 	(8) Heuristic Crossover............... 	26
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 25
# Maximum Nonchanging Generations: 4
# Population size       : 200
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 8.240035e-03  1.249765e-02  2.080866e-02  2.495064e-02  2.495064e-02  4.634828e-02  1.119860e-01  6.937781e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 200, #Total UniqueCount: 200
# var 1:
# best............ 7.029147e+01
# mean............ 5.151436e+02
# variance........ 7.516901e+04
# var 2:
# best............ 3.247996e+02
# mean............ 5.285927e+02
# variance........ 8.278485e+04
# var 3:
# best............ 4.586874e+02
# mean............ 4.823456e+02
# variance........ 8.984940e+04
# var 4:
# best............ 9.952261e+02
# mean............ 4.855264e+02
# variance........ 8.157988e+04
# var 5:
# best............ 8.986969e+02
# mean............ 5.302244e+02
# variance........ 7.907356e+04
# var 6:
# best............ 5.727523e+02
# mean............ 5.192616e+02
# variance........ 7.718702e+04
#
# GENERATION: 1
# Lexical Fit..... 9.088088e-03  1.206689e-02  1.206689e-02  1.249765e-02  1.559684e-02  4.634828e-02  1.119860e-01  4.540085e-01  6.937781e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 149, #Total UniqueCount: 349
# var 1:
# best............ 6.794610e+01
# mean............ 1.575918e+02
# variance........ 3.489879e+04
# var 2:
# best............ 5.500093e+02
# mean............ 4.872676e+02
# variance........ 5.696787e+04
# var 3:
# best............ 4.358661e+02
# mean............ 5.245307e+02
# variance........ 4.106569e+04
# var 4:
# best............ 6.278266e+02
# mean............ 6.083544e+02
# variance........ 1.158330e+05
# var 5:
# best............ 7.635610e+02
# mean............ 5.881192e+02
# variance........ 9.527660e+04
# var 6:
# best............ 6.190453e+02
# mean............ 6.684675e+02
# variance........ 3.123863e+04
#
# GENERATION: 2
# Lexical Fit..... 1.060990e-02  1.206689e-02  1.206689e-02  1.537171e-02  4.278935e-02  4.634828e-02  4.634828e-02  6.471049e-01  9.539091e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 148, #Total UniqueCount: 497
# var 1:
# best............ 6.753002e+01
# mean............ 9.778201e+01
# variance........ 1.057792e+04
# var 2:
# best............ 7.582562e+02
# mean............ 5.053294e+02
# variance........ 1.607664e+04
# var 3:
# best............ 4.385623e+02
# mean............ 4.402759e+02
# variance........ 7.703031e+03
# var 4:
# best............ 5.347773e+02
# mean............ 6.595782e+02
# variance........ 5.655629e+04
# var 5:
# best............ 1.315037e+02
# mean............ 7.523024e+02
# variance........ 1.857775e+04
# var 6:
# best............ 6.479798e+02
# mean............ 6.244185e+02
# variance........ 7.235042e+03
#
# GENERATION: 3
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 157, #Total UniqueCount: 654
# var 1:
# best............ 6.740047e+01
# mean............ 8.209637e+01
# variance........ 5.338406e+03
# var 2:
# best............ 7.925829e+02
# mean............ 6.374199e+02
# variance........ 1.412077e+04
# var 3:
# best............ 4.357219e+02
# mean............ 4.423291e+02
# variance........ 6.235626e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.716002e+02
# variance........ 8.404736e+03
# var 5:
# best............ 1.888723e+01
# mean............ 4.663678e+02
# variance........ 8.213599e+04
# var 6:
# best............ 6.533777e+02
# mean............ 6.302941e+02
# variance........ 5.195572e+03
#
# GENERATION: 4
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 149, #Total UniqueCount: 803
# var 1:
# best............ 6.740047e+01
# mean............ 9.631156e+01
# variance........ 1.447262e+04
# var 2:
# best............ 7.925829e+02
# mean............ 7.450507e+02
# variance........ 1.012662e+04
# var 3:
# best............ 4.357219e+02
# mean............ 4.419919e+02
# variance........ 2.130490e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.366597e+02
# variance........ 8.457205e+03
# var 5:
# best............ 1.888723e+01
# mean............ 1.445680e+02
# variance........ 4.746840e+04
# var 6:
# best............ 6.533777e+02
# mean............ 6.512207e+02
# variance........ 3.474440e+03
#
# GENERATION: 5
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 143, #Total UniqueCount: 946
# var 1:
# best............ 6.740047e+01
# mean............ 9.714340e+01
# variance........ 1.172343e+04
# var 2:
# best............ 7.925829e+02
# mean............ 7.802382e+02
# variance........ 4.074171e+03
# var 3:
# best............ 4.357219e+02
# mean............ 4.394539e+02
# variance........ 3.156310e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.284434e+02
# variance........ 4.168243e+03
# var 5:
# best............ 1.888723e+01
# mean............ 4.200291e+01
# variance........ 1.451262e+04
# var 6:
# best............ 6.533777e+02
# mean............ 6.406004e+02
# variance........ 4.823779e+03
#
# GENERATION: 6
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 125, #Total UniqueCount: 1071
# var 1:
# best............ 6.740047e+01
# mean............ 8.915584e+01
# variance........ 7.644519e+03
# var 2:
# best............ 7.925829e+02
# mean............ 7.756939e+02
# variance........ 9.588477e+03
# var 3:
# best............ 4.357219e+02
# mean............ 4.418372e+02
# variance........ 4.873719e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.229916e+02
# variance........ 3.884556e+03
# var 5:
# best............ 1.888723e+01
# mean............ 4.523966e+01
# variance........ 1.447554e+04
# var 6:
# best............ 6.533777e+02
# mean............ 6.407116e+02
# variance........ 9.603645e+03
#
# GENERATION: 7
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 132, #Total UniqueCount: 1203
# var 1:
# best............ 6.740047e+01
# mean............ 7.170111e+01
# variance........ 5.079082e+02
# var 2:
# best............ 7.925829e+02
# mean............ 7.827595e+02
# variance........ 5.452806e+03
# var 3:
# best............ 4.357219e+02
# mean............ 4.439239e+02
# variance........ 6.393474e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.205478e+02
# variance........ 4.014961e+03
# var 5:
# best............ 1.888723e+01
# mean............ 2.827206e+01
# variance........ 3.745368e+03
# var 6:
# best............ 6.533777e+02
# mean............ 6.425574e+02
# variance........ 3.693731e+03
#
# GENERATION: 8
# Lexical Fit..... 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
# #unique......... 128, #Total UniqueCount: 1331
# var 1:
# best............ 6.740047e+01
# mean............ 8.668185e+01
# variance........ 8.337266e+03
# var 2:
# best............ 7.925829e+02
# mean............ 7.699437e+02
# variance........ 1.150684e+04
# var 3:
# best............ 4.357219e+02
# mean............ 4.355650e+02
# variance........ 1.629283e+03
# var 4:
# best............ 5.293256e+02
# mean............ 5.297752e+02
# variance........ 2.658617e+03
# var 5:
# best............ 1.888723e+01
# mean............ 3.543516e+01
# variance........ 9.917276e+03
# var 6:
# best............ 6.533777e+02
# mean............ 6.438574e+02
# variance........ 3.973465e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 4 generations.
#
# Solution Lexical Fitness Value:
# 1.465107e-02  1.507627e-02  2.495064e-02  2.495064e-02  4.634828e-02  7.939617e-02  1.119860e-01  4.558019e-01  7.344067e-01  9.539091e-01  1.000000e+00  1.000000e+00
#
# Parameters at the Solution:
#
#  X[ 1] :	6.740047e+01
#  X[ 2] :	7.925829e+02
#  X[ 3] :	4.357219e+02
#  X[ 4] :	5.293256e+02
#  X[ 5] :	1.888723e+01
#  X[ 6] :	6.533777e+02
#
# Solution Found Generation 3
# Number of Generations Run 8
#
# Tue Apr 23 17:13:35 2019
# Total run time : 0 hours 0 minutes and 3 seconds
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  17
# Matched number of observations  (unweighted).  17

# %%
mb1  <- MatchBalance(Tr ~  incparty + s_black + 
    college + SenElection + factor(fips_state) + factor(year), 
    data = state.data.t4.match, match.out = mout1, nboots=500)
# Out:
# ***** (V1) incpartyR *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.23529 	 	    0.23529
# mean control..........    0.62745 	 	    0.58824
# std mean diff.........     -89.69 	 	    -80.721
#
# mean raw eQQ diff.....    0.35294 	 	    0.35294
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.19608 	 	    0.17647
# med  eCDF diff........    0.19608 	 	    0.17647
# max  eCDF diff........    0.39216 	 	    0.35294
#
# var ratio (Tr/Co).....    0.80181 	 	    0.74286
# T-test p-value........  0.0040663 	 	   0.024951
#
#
# ***** (V2) s_black *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.086503 	 	   0.086503
# mean control..........   0.085878 	 	   0.058679
# std mean diff.........    0.87156 	 	     38.792
#
# mean raw eQQ diff.....   0.020856 	 	   0.029492
# med  raw eQQ diff.....      0.005 	 	    0.01118
# max  raw eQQ diff.....   0.096853 	 	   0.088158
#
# mean eCDF diff........   0.063072 	 	    0.11312
# med  eCDF diff........    0.04902 	 	   0.088235
# max  eCDF diff........    0.17647 	 	    0.41176
#
# var ratio (Tr/Co).....    0.69237 	 	     1.3089
# T-test p-value........    0.97663 	 	   0.015076
# KS Bootstrap p-value..      0.766 	 	      0.088
# KS Naive p-value......    0.82206 	 	    0.11199
# KS Statistic..........    0.17647 	 	    0.41176
#
#
# ***** (V3) college *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17716 	 	    0.17716
# mean control..........    0.25964 	 	    0.20313
# std mean diff.........    -171.42 	 	    -53.964
#
# mean raw eQQ diff.....   0.081266 	 	   0.031218
# med  raw eQQ diff.....   0.079406 	 	   0.031482
# max  raw eQQ diff.....    0.12111 	 	   0.063496
#
# mean eCDF diff........    0.37082 	 	    0.20479
# med  eCDF diff........    0.36275 	 	    0.23529
# max  eCDF diff........    0.64706 	 	    0.47059
#
# var ratio (Tr/Co).....    0.69641 	 	     1.6693
# T-test p-value........ 1.7513e-06 	 	   0.014651
# KS Bootstrap p-value.. < 2.22e-16 	 	      0.042
# KS Naive p-value...... 1.7413e-05 	 	   0.046348
# KS Statistic..........    0.64706 	 	    0.47059
#
#
# ***** (V4) SenElection *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.70588 	 	    0.70588
# mean control..........    0.64706 	 	    0.70588
# std mean diff.........     12.524 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....    0.94697 	 	          1
# T-test p-value........    0.66036 	 	          1
#
#
# ***** (V5) factor(fips_state)2 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     24.254
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.029412
# med  eCDF diff........   0.029412 	 	   0.029412
# max  eCDF diff........   0.058824 	 	   0.058824
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.31798
#
#
# ***** (V6) factor(fips_state)4 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V7) factor(fips_state)5 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     24.254
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.029412
# med  eCDF diff........   0.029412 	 	   0.029412
# max  eCDF diff........   0.058824 	 	   0.058824
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.31798
#
#
# ***** (V8) factor(fips_state)6 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     24.254
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.029412
# med  eCDF diff........   0.029412 	 	   0.029412
# max  eCDF diff........   0.058824 	 	   0.058824
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.31798
#
#
# ***** (V9) factor(fips_state)8 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.058824 	 	          0
# std mean diff.........          0 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........          0 	 	   0.029412
# med  eCDF diff........          0 	 	   0.029412
# max  eCDF diff........          0 	 	   0.058824
#
# var ratio (Tr/Co).....     1.0417 	 	        Inf
# T-test p-value........          1 	 	    0.31798
#
#
# ***** (V10) factor(fips_state)9 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.078431 	 	    0.29412
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.29412
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.039216 	 	    0.14706
# med  eCDF diff........   0.039216 	 	    0.14706
# max  eCDF diff........   0.078431 	 	    0.29412
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.044341 	 	   0.017066
#
#
# ***** (V11) factor(fips_state)12 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V12) factor(fips_state)13 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V13) factor(fips_state)16 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.029412
# med  eCDF diff........   0.019608 	 	   0.029412
# max  eCDF diff........   0.039216 	 	   0.058824
#
# var ratio (Tr/Co).....          3 	 	        Inf
# T-test p-value........    0.53437 	 	    0.31798
#
#
# ***** (V14) factor(fips_state)17 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.039216 	 	          0
# std mean diff.........     8.0845 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.029412
# med  eCDF diff........  0.0098039 	 	   0.029412
# max  eCDF diff........   0.019608 	 	   0.058824
#
# var ratio (Tr/Co).....     1.5306 	 	        Inf
# T-test p-value........    0.76528 	 	    0.31798
#
#
# ***** (V15) factor(fips_state)19 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.098039 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....    0.11765 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.04902 	 	          0
# med  eCDF diff........    0.04902 	 	          0
# max  eCDF diff........   0.098039 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.023811 	 	          1
#
#
# ***** (V16) factor(fips_state)20 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V17) factor(fips_state)24 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083202 	 	          1
#
#
# ***** (V18) factor(fips_state)25 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V19) factor(fips_state)26 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11765 	 	    0.11765
# mean control..........   0.019608 	 	          0
# std mean diff.........      29.52 	 	     35.425
#
# mean raw eQQ diff.....   0.058824 	 	    0.11765
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.04902 	 	   0.058824
# med  eCDF diff........    0.04902 	 	   0.058824
# max  eCDF diff........   0.098039 	 	    0.11765
#
# var ratio (Tr/Co).....      5.625 	 	        Inf
# T-test p-value........     0.2524 	 	    0.15167
#
#
# ***** (V20) factor(fips_state)27 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083202 	 	          1
#
#
# ***** (V21) factor(fips_state)31 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	   0.058824
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.029412
# med  eCDF diff........   0.029412 	 	   0.029412
# max  eCDF diff........   0.058824 	 	   0.058824
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.083202 	 	    0.31798
#
#
# ***** (V22) factor(fips_state)32 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V23) factor(fips_state)33 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	    0.11765
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.11765
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.058824
# med  eCDF diff........   0.019608 	 	   0.058824
# max  eCDF diff........   0.039216 	 	    0.11765
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.15934 	 	    0.15167
#
#
# ***** (V24) factor(fips_state)35 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	   0.058824
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	          1
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V25) factor(fips_state)36 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V26) factor(fips_state)39 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.029412
# med  eCDF diff........   0.019608 	 	   0.029412
# max  eCDF diff........   0.039216 	 	   0.058824
#
# var ratio (Tr/Co).....          3 	 	        Inf
# T-test p-value........    0.53437 	 	    0.31798
#
#
# ***** (V27) factor(fips_state)40 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.029412
# med  eCDF diff........   0.019608 	 	   0.029412
# max  eCDF diff........   0.039216 	 	   0.058824
#
# var ratio (Tr/Co).....          3 	 	        Inf
# T-test p-value........    0.53437 	 	    0.31798
#
#
# ***** (V28) factor(fips_state)41 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11765 	 	    0.11765
# mean control..........          0 	 	          0
# std mean diff.........     35.425 	 	     35.425
#
# mean raw eQQ diff.....    0.11765 	 	    0.11765
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.058824 	 	   0.058824
# med  eCDF diff........   0.058824 	 	   0.058824
# max  eCDF diff........    0.11765 	 	    0.11765
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.16349 	 	    0.15167
#
#
# ***** (V29) factor(fips_state)44 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	    0.17647
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.17647
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.088235
# med  eCDF diff........  0.0098039 	 	   0.088235
# max  eCDF diff........   0.019608 	 	    0.17647
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32213 	 	   0.074415
#
#
# ***** (V30) factor(fips_state)45 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V31) factor(fips_state)47 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	   0.058824
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	          1
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V32) factor(fips_state)48 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     24.254
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.029412
# med  eCDF diff........   0.029412 	 	   0.029412
# max  eCDF diff........   0.058824 	 	   0.058824
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.31798
#
#
# ***** (V33) factor(fips_state)50 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	   0.058824
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.029412
# med  eCDF diff........  0.0098039 	 	   0.029412
# max  eCDF diff........   0.019608 	 	   0.058824
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32213 	 	    0.31798
#
#
# ***** (V34) factor(fips_state)55 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	    0.11765
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.11765
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.058824
# med  eCDF diff........   0.029412 	 	   0.058824
# max  eCDF diff........   0.058824 	 	    0.11765
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.083202 	 	    0.15167
#
#
# ***** (V35) factor(fips_state)56 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.029412
# med  eCDF diff........   0.019608 	 	   0.029412
# max  eCDF diff........   0.039216 	 	   0.058824
#
# var ratio (Tr/Co).....          3 	 	        Inf
# T-test p-value........    0.53437 	 	    0.31798
#
#
# ***** (V36) factor(year)1990 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.078431 	 	    0.11765
# std mean diff.........    -8.0845 	 	    -24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.029412
# med  eCDF diff........  0.0098039 	 	   0.029412
# max  eCDF diff........   0.019608 	 	   0.058824
#
# var ratio (Tr/Co).....    0.79787 	 	    0.53333
# T-test p-value........    0.78141 	 	    0.56796
#
#
# ***** (V37) factor(year)1994 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.098039 	 	   0.058824
# std mean diff.........    -16.169 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....    0.65217 	 	          1
# T-test p-value........    0.59116 	 	          1
#
#
# ***** (V38) factor(year)1998 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.31373 	 	    0.11765
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.29412 	 	    0.11765
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.15686 	 	   0.058824
# med  eCDF diff........    0.15686 	 	   0.058824
# max  eCDF diff........    0.31373 	 	    0.11765
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........ 1.5767e-05 	 	    0.15167
#
#
# ***** (V39) factor(year)2002 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	   0.058824
# mean control..........   0.058824 	 	          0
# std mean diff.........          0 	 	     24.254
#
# mean raw eQQ diff.....          0 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........          0 	 	   0.029412
# med  eCDF diff........          0 	 	   0.029412
# max  eCDF diff........          0 	 	   0.058824
#
# var ratio (Tr/Co).....     1.0417 	 	        Inf
# T-test p-value........          1 	 	    0.31798
#
#
# ***** (V40) factor(year)2006 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.35294 	 	   0.058824
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.35294 	 	   0.058824
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.17647 	 	   0.029412
# med  eCDF diff........    0.17647 	 	   0.029412
# max  eCDF diff........    0.35294 	 	   0.058824
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........ 3.4343e-06 	 	    0.31798
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): college  Number(s): 3
#
# After Matching Minimum p.value: 0.014651
# Variable Name(s): college  Number(s): 3

# %%
# checking effect

mout1y = Match(Tr = Tr, X = X, Y= state.data.t4.match$vep, Weight.matrix=genout1)
summary(mout1y)
# Out:
# Estimate...  0.028824
# AI SE......  0.024583
# T-stat.....  1.1725
# p.val......  0.241
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  17
# Matched number of observations  (unweighted).  17

# %% [markdown]
# #### Trying to Improve GenMatch

# %%
dim(state.data.t4.match)
# Out:
# [1] 68 30

# %%
genout2 = GenMatch(Tr = Tr, X = X,pop.size=200,max.generations=25,caliper=1)
mout2 = Match(Tr = Tr, X = X, Weight.matrix=genout2,caliper=1)
summary(mout2)
# Out:
# Tue Apr 23 17:13:35 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	22
# 	(2) Uniform Mutation.................. 	25
# 	(3) Boundary Mutation................. 	25
# 	(4) Non-Uniform Mutation.............. 	25
# 	(5) Polytope Crossover................ 	25
# 	(6) Simple Crossover.................. 	26
# 	(7) Whole Non-Uniform Mutation........ 	25
# 	(8) Heuristic Crossover............... 	26
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 25
# Maximum Nonchanging Generations: 4
# Population size       : 200
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 200, #Total UniqueCount: 200
# var 1:
# best............ 1.000000e+00
# mean............ 4.986307e+02
# variance........ 8.408792e+04
# var 2:
# best............ 1.000000e+00
# mean............ 5.119406e+02
# variance........ 8.322096e+04
# var 3:
# best............ 1.000000e+00
# mean............ 4.823807e+02
# variance........ 7.923640e+04
# var 4:
# best............ 1.000000e+00
# mean............ 4.989106e+02
# variance........ 8.086340e+04
# var 5:
# best............ 1.000000e+00
# mean............ 5.117902e+02
# variance........ 8.451833e+04
# var 6:
# best............ 1.000000e+00
# mean............ 4.936397e+02
# variance........ 8.990701e+04
#
# GENERATION: 1
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 150, #Total UniqueCount: 350
# var 1:
# best............ 1.000000e+00
# mean............ 2.871253e+02
# variance........ 8.538926e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.821218e+02
# variance........ 6.626627e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.256846e+02
# variance........ 6.325257e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.164502e+02
# variance........ 9.440646e+04
# var 5:
# best............ 1.000000e+00
# mean............ 2.940250e+02
# variance........ 9.885440e+04
# var 6:
# best............ 1.000000e+00
# mean............ 3.364234e+02
# variance........ 1.001998e+05
#
# GENERATION: 2
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 141, #Total UniqueCount: 491
# var 1:
# best............ 1.000000e+00
# mean............ 2.843801e+02
# variance........ 7.715707e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.914502e+02
# variance........ 7.038810e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.163067e+02
# variance........ 6.298999e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.301104e+02
# variance........ 1.024490e+05
# var 5:
# best............ 1.000000e+00
# mean............ 2.539825e+02
# variance........ 8.895865e+04
# var 6:
# best............ 1.000000e+00
# mean............ 3.548338e+02
# variance........ 1.081978e+05
#
# GENERATION: 3
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 131, #Total UniqueCount: 622
# var 1:
# best............ 1.000000e+00
# mean............ 2.855834e+02
# variance........ 8.205350e+04
# var 2:
# best............ 1.000000e+00
# mean............ 1.858551e+02
# variance........ 6.593330e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.384430e+02
# variance........ 6.712585e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.346306e+02
# variance........ 1.019994e+05
# var 5:
# best............ 1.000000e+00
# mean............ 2.746549e+02
# variance........ 1.007682e+05
# var 6:
# best............ 1.000000e+00
# mean............ 3.565962e+02
# variance........ 1.026891e+05
#
# GENERATION: 4
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 135, #Total UniqueCount: 757
# var 1:
# best............ 1.000000e+00
# mean............ 3.176173e+02
# variance........ 7.465033e+04
# var 2:
# best............ 1.000000e+00
# mean............ 2.246180e+02
# variance........ 7.403363e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.433079e+02
# variance........ 6.001359e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.885692e+02
# variance........ 1.161285e+05
# var 5:
# best............ 1.000000e+00
# mean............ 2.827356e+02
# variance........ 9.154229e+04
# var 6:
# best............ 1.000000e+00
# mean............ 4.250847e+02
# variance........ 1.168024e+05
#
# GENERATION: 5
# Lexical Fit..... 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 127, #Total UniqueCount: 884
# var 1:
# best............ 1.000000e+00
# mean............ 3.202471e+02
# variance........ 7.823387e+04
# var 2:
# best............ 1.000000e+00
# mean............ 2.085574e+02
# variance........ 7.146299e+04
# var 3:
# best............ 1.000000e+00
# mean............ 2.272848e+02
# variance........ 6.623641e+04
# var 4:
# best............ 1.000000e+00
# mean............ 3.515541e+02
# variance........ 1.059391e+05
# var 5:
# best............ 1.000000e+00
# mean............ 2.672413e+02
# variance........ 8.420734e+04
# var 6:
# best............ 1.000000e+00
# mean............ 3.807157e+02
# variance........ 1.068918e+05
#
# 'wait.generations' limit reached.
# No significant improvement in 4 generations.
#
# Solution Lexical Fitness Value:
# 5.797277e-02  5.394082e-01  8.395056e-01  8.927783e-01  8.927783e-01  8.927783e-01  9.337263e-01  9.999968e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
# Parameters at the Solution:
#
#  X[ 1] :	1.000000e+00
#  X[ 2] :	1.000000e+00
#  X[ 3] :	1.000000e+00
#  X[ 4] :	1.000000e+00
#  X[ 5] :	1.000000e+00
#  X[ 6] :	1.000000e+00
#
# Solution Found Generation 1
# Number of Generations Run 5
#
# Tue Apr 23 17:13:37 2019
# Total run time : 0 hours 0 minutes and 2 seconds
#
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  6
# Matched number of observations  (unweighted).  6
#
# Caliper (SDs)........................................   1 1 1 1 1 1
# Number of obs dropped by 'exact' or 'caliper'  11

# %%
mb2  <- MatchBalance(Tr ~  incparty + s_black + 
    college + SenElection + factor(fips_state) + factor(year), 
    data = state.data.t4.match, match.out = mout2, nboots=500)
# Out:
# ***** (V1) incpartyR *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.23529 	 	    0.33333
# mean control..........    0.62745 	 	    0.33333
# std mean diff.........     -89.69 	 	          0
#
# mean raw eQQ diff.....    0.35294 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.19608 	 	          0
# med  eCDF diff........    0.19608 	 	          0
# max  eCDF diff........    0.39216 	 	          0
#
# var ratio (Tr/Co).....    0.80181 	 	          1
# T-test p-value........  0.0040663 	 	          1
#
#
# ***** (V2) s_black *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.086503 	 	   0.040257
# mean control..........   0.085878 	 	   0.036908
# std mean diff.........    0.87156 	 	     13.169
#
# mean raw eQQ diff.....   0.020856 	 	  0.0050211
# med  raw eQQ diff.....      0.005 	 	  0.0042818
# max  raw eQQ diff.....   0.096853 	 	   0.011901
#
# mean eCDF diff........   0.063072 	 	    0.12121
# med  eCDF diff........    0.04902 	 	    0.16667
# max  eCDF diff........    0.17647 	 	    0.33333
#
# var ratio (Tr/Co).....    0.69237 	 	    0.86141
# T-test p-value........    0.97663 	 	    0.83951
# KS Bootstrap p-value..       0.76 	 	      0.808
# KS Naive p-value......    0.82206 	 	    0.89278
# KS Statistic..........    0.17647 	 	    0.33333
#
#
# ***** (V3) college *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17716 	 	    0.22134
# mean control..........    0.25964 	 	    0.22961
# std mean diff.........    -171.42 	 	    -15.879
#
# mean raw eQQ diff.....   0.081266 	 	   0.022346
# med  raw eQQ diff.....   0.079406 	 	   0.019237
# max  raw eQQ diff.....    0.12111 	 	   0.046293
#
# mean eCDF diff........    0.37082 	 	    0.10606
# med  eCDF diff........    0.36275 	 	    0.16667
# max  eCDF diff........    0.64706 	 	    0.33333
#
# var ratio (Tr/Co).....    0.69641 	 	     2.8481
# T-test p-value........ 1.7513e-06 	 	    0.53941
# KS Bootstrap p-value.. < 2.22e-16 	 	       0.82
# KS Naive p-value...... 1.7413e-05 	 	    0.89278
# KS Statistic..........    0.64706 	 	    0.33333
#
#
# ***** (V4) SenElection *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.70588 	 	          1
# mean control..........    0.64706 	 	          1
# std mean diff.........     12.524 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....    0.94697 	 	        NaN
# T-test p-value........    0.66036 	 	          1
#
#
# ***** (V5) factor(fips_state)2 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     40.825
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.083333
# med  eCDF diff........   0.029412 	 	   0.083333
# max  eCDF diff........   0.058824 	 	    0.16667
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.32326
#
#
# ***** (V6) factor(fips_state)4 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	    0.16667
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.083333
# med  eCDF diff........   0.019608 	 	   0.083333
# max  eCDF diff........   0.039216 	 	    0.16667
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.15934 	 	    0.32326
#
#
# ***** (V7) factor(fips_state)5 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....        Inf 	 	        NaN
# T-test p-value........    0.33219 	 	          1
#
#
# ***** (V8) factor(fips_state)6 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	     40.825
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.083333
# med  eCDF diff........   0.029412 	 	   0.083333
# max  eCDF diff........   0.058824 	 	    0.16667
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.33219 	 	    0.32326
#
#
# ***** (V9) factor(fips_state)8 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........   0.058824 	 	          0
# std mean diff.........          0 	 	     40.825
#
# mean raw eQQ diff.....          0 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........          0 	 	   0.083333
# med  eCDF diff........          0 	 	   0.083333
# max  eCDF diff........          0 	 	    0.16667
#
# var ratio (Tr/Co).....     1.0417 	 	        Inf
# T-test p-value........          1 	 	    0.32326
#
#
# ***** (V10) factor(fips_state)9 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.078431 	 	    0.33333
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.33333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.039216 	 	    0.16667
# med  eCDF diff........   0.039216 	 	    0.16667
# max  eCDF diff........   0.078431 	 	    0.33333
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.044341 	 	    0.14381
#
#
# ***** (V11) factor(fips_state)12 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V12) factor(fips_state)13 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V13) factor(fips_state)16 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	        NaN
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V14) factor(fips_state)17 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........     8.0845 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....     1.5306 	 	        NaN
# T-test p-value........    0.76528 	 	          1
#
#
# ***** (V15) factor(fips_state)19 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.098039 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....    0.11765 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.04902 	 	          0
# med  eCDF diff........    0.04902 	 	          0
# max  eCDF diff........   0.098039 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.023811 	 	          1
#
#
# ***** (V16) factor(fips_state)20 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V17) factor(fips_state)24 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083202 	 	          1
#
#
# ***** (V18) factor(fips_state)25 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V19) factor(fips_state)26 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11765 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........      29.52 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.04902 	 	          0
# med  eCDF diff........    0.04902 	 	          0
# max  eCDF diff........   0.098039 	 	          0
#
# var ratio (Tr/Co).....      5.625 	 	        NaN
# T-test p-value........     0.2524 	 	          1
#
#
# ***** (V20) factor(fips_state)27 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083202 	 	          1
#
#
# ***** (V21) factor(fips_state)31 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	    0.16667
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029412 	 	   0.083333
# med  eCDF diff........   0.029412 	 	   0.083333
# max  eCDF diff........   0.058824 	 	    0.16667
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.083202 	 	    0.32326
#
#
# ***** (V22) factor(fips_state)32 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V23) factor(fips_state)33 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.039216 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15934 	 	          1
#
#
# ***** (V24) factor(fips_state)35 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.019608 	 	    0.16667
# std mean diff.........     16.169 	 	       -Inf
#
# mean raw eQQ diff.....          0 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.083333
# med  eCDF diff........   0.019608 	 	   0.083333
# max  eCDF diff........   0.039216 	 	    0.16667
#
# var ratio (Tr/Co).....          3 	 	          0
# T-test p-value........    0.53437 	 	    0.32326
#
#
# ***** (V25) factor(fips_state)36 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V26) factor(fips_state)39 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	        NaN
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V27) factor(fips_state)40 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	     40.825
#
# mean raw eQQ diff.....          0 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.083333
# med  eCDF diff........   0.019608 	 	   0.083333
# max  eCDF diff........   0.039216 	 	    0.16667
#
# var ratio (Tr/Co).....          3 	 	        Inf
# T-test p-value........    0.53437 	 	    0.32326
#
#
# ***** (V28) factor(fips_state)41 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11765 	 	    0.33333
# mean control..........          0 	 	          0
# std mean diff.........     35.425 	 	      64.55
#
# mean raw eQQ diff.....    0.11765 	 	    0.33333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.058824 	 	    0.16667
# med  eCDF diff........   0.058824 	 	    0.16667
# max  eCDF diff........    0.11765 	 	    0.33333
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.16349 	 	    0.14381
#
#
# ***** (V29) factor(fips_state)44 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V30) factor(fips_state)45 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0098039 	 	          0
# med  eCDF diff........  0.0098039 	 	          0
# max  eCDF diff........   0.019608 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32213 	 	          1
#
#
# ***** (V31) factor(fips_state)47 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	        NaN
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V32) factor(fips_state)48 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........          0 	 	          0
# std mean diff.........     24.254 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....        Inf 	 	        NaN
# T-test p-value........    0.33219 	 	          1
#
#
# ***** (V33) factor(fips_state)50 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.019608 	 	    0.16667
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.083333
# med  eCDF diff........  0.0098039 	 	   0.083333
# max  eCDF diff........   0.019608 	 	    0.16667
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32213 	 	    0.32326
#
#
# ***** (V34) factor(fips_state)55 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.058824 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....   0.058824 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.029412 	 	          0
# med  eCDF diff........   0.029412 	 	          0
# max  eCDF diff........   0.058824 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083202 	 	          1
#
#
# ***** (V35) factor(fips_state)56 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.019608 	 	          0
# std mean diff.........     16.169 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.019608 	 	          0
# med  eCDF diff........   0.019608 	 	          0
# max  eCDF diff........   0.039216 	 	          0
#
# var ratio (Tr/Co).....          3 	 	        NaN
# T-test p-value........    0.53437 	 	          1
#
#
# ***** (V36) factor(year)1990 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	          0
# mean control..........   0.078431 	 	    0.16667
# std mean diff.........    -8.0845 	 	       -Inf
#
# mean raw eQQ diff.....          0 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0098039 	 	   0.083333
# med  eCDF diff........  0.0098039 	 	   0.083333
# max  eCDF diff........   0.019608 	 	    0.16667
#
# var ratio (Tr/Co).....    0.79787 	 	          0
# T-test p-value........    0.78141 	 	    0.32326
#
#
# ***** (V37) factor(year)1994 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........   0.098039 	 	          0
# std mean diff.........    -16.169 	 	     40.825
#
# mean raw eQQ diff.....   0.058824 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.019608 	 	   0.083333
# med  eCDF diff........   0.019608 	 	   0.083333
# max  eCDF diff........   0.039216 	 	    0.16667
#
# var ratio (Tr/Co).....    0.65217 	 	        Inf
# T-test p-value........    0.59116 	 	    0.32326
#
#
# ***** (V38) factor(year)1998 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.31373 	 	    0.16667
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.29412 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.15686 	 	   0.083333
# med  eCDF diff........    0.15686 	 	   0.083333
# max  eCDF diff........    0.31373 	 	    0.16667
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........ 1.5767e-05 	 	    0.32326
#
#
# ***** (V39) factor(year)2002 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058824 	 	    0.16667
# mean control..........   0.058824 	 	          0
# std mean diff.........          0 	 	     40.825
#
# mean raw eQQ diff.....          0 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........          0 	 	   0.083333
# med  eCDF diff........          0 	 	   0.083333
# max  eCDF diff........          0 	 	    0.16667
#
# var ratio (Tr/Co).....     1.0417 	 	        Inf
# T-test p-value........          1 	 	    0.32326
#
#
# ***** (V40) factor(year)2006 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.35294 	 	    0.16667
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.35294 	 	    0.16667
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.17647 	 	   0.083333
# med  eCDF diff........    0.17647 	 	   0.083333
# max  eCDF diff........    0.35294 	 	    0.16667
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........ 3.4343e-06 	 	    0.32326
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): college  Number(s): 3
#
# After Matching Minimum p.value: 0.14381
# Variable Name(s): factor(fips_state)9 factor(fips_state)41  Number(s): 10 28

# %%
mout2y = Match(Tr = Tr, X = X, Y = state.data.t4.match$vep, Weight.matrix=genout2,caliper=1)
summary(mout2y)
# Out:
# Estimate...  0.051667
# AI SE......  0.016005
# T-stat.....  3.2282
# p.val......  0.0012457
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  6
# Matched number of observations  (unweighted).  6
#
# Caliper (SDs)........................................   1 1 1 1 1 1
# Number of obs dropped by 'exact' or 'caliper'  11

# %% [markdown]
# **Dropped too many**
#
# While we got the exact same coefficient on state unemployment rate, we've dropped so many variables that it is no longer generalizable to the whole population (left with 6 treatment obs, dropped 11).
#
# Since match balance can only be achieved when dropping a significant ammount of variables, we can conclude that the treatment and observation groups are statistically significantly different and hence there is already inherent selection bias in the observations that is not controlled for. The incumbent party, college, and other factors significantly affect unemployment rate in a way that cannot be controlled for given the data we have. Thus, to isolate the effect of unemployment

# %% [markdown]
# # Sensitivity Analysis on Bad Match

# %%
library('rbounds') 

psens(mout1y, Gamma = 2, GammaInc = 0.1)
# Out:
#  Rosenbaum Sensitivity Test for Wilcoxon Signed Rank P-Value
#
# Unconfounded estimate ....  0.0776
#
#  Gamma Lower bound Upper bound
#    1.0      0.0776      0.0776
#    1.1      0.0553      0.1056
#    1.2      0.0394      0.1365
#    1.3      0.0280      0.1693
#    1.4      0.0200      0.2036
#    1.5      0.0142      0.2386
#    1.6      0.0102      0.2739
#    1.7      0.0073      0.3090
#    1.8      0.0052      0.3436
#    1.9      0.0037      0.3775
#    2.0      0.0026      0.4105
#
#  Note: Gamma is Odds of Differential Assignment To
#  Treatment Due to Unobserved Factors

# %% [markdown]
# Fairly insensitive
# - still significant at gamma 1
# - still significant at gamma = 2*p-val = 2*0.241 = ~5

# %% [markdown]
# ### Gen Match for effect of Republican Incumbent

# %%
# Gen Match
library('Matching')
library('rgenoud')

Trr = ifelse(state.data.t4.match$incparty =='R', 1, 0)

Xr = cbind(state.data.t4.match$uerate, 
          state.data.t4.match$s_black, state.data.t4.match$college, 
          state.data.t4.match$SenElection, factor(state.data.t4.match$fips_state),
          factor(state.data.t4.match$year))


# X = cbind(state.data.t4.match$year,state.data.t4.match$fips_state,
#       state.data.t4.match$s_black, state.data.t4.match$SenElection,
#       state.data.t4.match$presyear, state.data.t4.match$college,
#       state.data.t4.match$college_diff, state.data.t4.match$pci_0000,
#       state.data.t4.match$prior_ue, state.data.t4.match$partyspending,
#       state.data.t4.match$priorue_diff, state.data.t4.match$spending_diff,
#       state.data.t4.match$share_open, state.data.t4.match$share_qual_out2,
#       state.data.t4.match$open_all_share, state.data.t4.match$quality_share_new,
#       state.data.t4.match$outparty_spend, state.data.t4.match$share_open_diff,
#       state.data.t4.match$open_all_share_diff, state.data.t4.match$share_qual_out2_diff,
#       state.data.t4.match$quality_share_diff, state.data.t4.match$outparty_spend_diff,
#       state.data.t4.match$s_black_diff, state.data.t4.match$pci0000_diff,
#       state.data.t4.match$senelec_diff, state.data.t4.match$incparty,
#       state.data.t4.match$GubElection, state.data.t4.match$vep,
#       state.data.t4.match$uerate)

genoutr1 = GenMatch(Tr = Trr, X = Xr,pop.size=200,max.generations=25)
moutr1 = Match(Tr = Trr, X = Xr, Weight.matrix=genoutr1)
summary(mout1r)
# Out:
# Tue Apr 23 18:06:36 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	22
# 	(2) Uniform Mutation.................. 	25
# 	(3) Boundary Mutation................. 	25
# 	(4) Non-Uniform Mutation.............. 	25
# 	(5) Polytope Crossover................ 	25
# 	(6) Simple Crossover.................. 	26
# 	(7) Whole Non-Uniform Mutation........ 	25
# 	(8) Heuristic Crossover............... 	26
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 25
# Maximum Nonchanging Generations: 4
# Population size       : 200
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 3.364049e-01  4.324895e-01  5.983877e-01  6.034282e-01  6.993742e-01  7.323487e-01  8.630853e-01  8.781816e-01  9.793631e-01  9.793631e-01  1.000000e+00  1.000000e+00
# #unique......... 200, #Total UniqueCount: 200
# var 1:
# best............ 5.844515e+02
# mean............ 4.986021e+02
# variance........ 7.876146e+04
# var 2:
# best............ 3.274260e+02
# mean............ 5.127231e+02
# variance........ 8.259673e+04
# var 3:
# best............ 9.373884e+02
# mean............ 5.152380e+02
# variance........ 8.582839e+04
# var 4:
# best............ 6.144595e+01
# mean............ 5.246102e+02
# variance........ 8.046856e+04
# var 5:
# best............ 3.409819e+02
# mean............ 5.196495e+02
# variance........ 8.412057e+04
# var 6:
# best............ 9.014919e+02
# mean............ 4.723180e+02
# variance........ 8.071986e+04
#
# GENERATION: 1
# Lexical Fit..... 5.041209e-01  6.697178e-01  6.966496e-01  6.993742e-01  7.498068e-01  7.979726e-01  8.243862e-01  9.793631e-01  9.793631e-01  9.996333e-01  1.000000e+00  1.000000e+00
# #unique......... 151, #Total UniqueCount: 351
# var 1:
# best............ 5.844515e+02
# mean............ 6.025018e+02
# variance........ 4.544083e+04
# var 2:
# best............ 3.274260e+02
# mean............ 3.270795e+02
# variance........ 4.316049e+04
# var 3:
# best............ 9.373884e+02
# mean............ 6.518010e+02
# variance........ 9.931382e+04
# var 4:
# best............ 6.144595e+01
# mean............ 3.007685e+02
# variance........ 6.580429e+04
# var 5:
# best............ 2.459631e+02
# mean............ 4.709857e+02
# variance........ 3.701623e+04
# var 6:
# best............ 9.014919e+02
# mean............ 7.755127e+02
# variance........ 5.327742e+04
#
# GENERATION: 2
# Lexical Fit..... 5.041209e-01  6.697178e-01  6.966496e-01  6.993742e-01  7.498068e-01  7.979726e-01  8.243862e-01  9.793631e-01  9.793631e-01  9.996333e-01  1.000000e+00  1.000000e+00
# #unique......... 148, #Total UniqueCount: 499
# var 1:
# best............ 5.844515e+02
# mean............ 5.831841e+02
# variance........ 4.696608e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.269047e+02
# variance........ 6.894050e+03
# var 3:
# best............ 9.373884e+02
# mean............ 9.177567e+02
# variance........ 6.760403e+03
# var 4:
# best............ 6.144595e+01
# mean............ 8.402499e+01
# variance........ 1.044083e+04
# var 5:
# best............ 2.459631e+02
# mean............ 3.452888e+02
# variance........ 2.750966e+04
# var 6:
# best............ 9.014919e+02
# mean............ 8.644882e+02
# variance........ 1.331167e+04
#
# GENERATION: 3
# Lexical Fit..... 5.041209e-01  6.697178e-01  6.966496e-01  6.993742e-01  7.498068e-01  7.979726e-01  8.243862e-01  9.793631e-01  9.793631e-01  9.996333e-01  1.000000e+00  1.000000e+00
# #unique......... 144, #Total UniqueCount: 643
# var 1:
# best............ 5.844515e+02
# mean............ 5.727900e+02
# variance........ 5.572074e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.353133e+02
# variance........ 7.106681e+03
# var 3:
# best............ 9.373884e+02
# mean............ 9.199150e+02
# variance........ 6.521116e+03
# var 4:
# best............ 6.144595e+01
# mean............ 8.341025e+01
# variance........ 7.427502e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.877440e+02
# variance........ 1.166119e+04
# var 6:
# best............ 9.014919e+02
# mean............ 8.808583e+02
# variance........ 9.043430e+03
#
# GENERATION: 4
# Lexical Fit..... 5.041209e-01  6.697178e-01  6.966496e-01  6.993742e-01  7.498068e-01  7.979726e-01  8.243862e-01  9.793631e-01  9.793631e-01  9.996333e-01  1.000000e+00  1.000000e+00
# #unique......... 135, #Total UniqueCount: 778
# var 1:
# best............ 5.844515e+02
# mean............ 5.793174e+02
# variance........ 3.398287e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.365006e+02
# variance........ 2.162253e+03
# var 3:
# best............ 9.373884e+02
# mean............ 9.129217e+02
# variance........ 6.288939e+03
# var 4:
# best............ 6.144595e+01
# mean............ 8.238864e+01
# variance........ 8.944426e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.685405e+02
# variance........ 6.769239e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.839135e+02
# variance........ 7.293767e+03
#
# GENERATION: 5
# Lexical Fit..... 5.041209e-01  6.697178e-01  6.966496e-01  6.993742e-01  7.498068e-01  7.979726e-01  8.243862e-01  9.793631e-01  9.793631e-01  9.996333e-01  1.000000e+00  1.000000e+00
# #unique......... 133, #Total UniqueCount: 911
# var 1:
# best............ 5.844515e+02
# mean............ 5.779710e+02
# variance........ 3.461063e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.351787e+02
# variance........ 6.110994e+03
# var 3:
# best............ 9.373884e+02
# mean............ 8.966585e+02
# variance........ 2.136380e+04
# var 4:
# best............ 6.144595e+01
# mean............ 8.562378e+01
# variance........ 1.001833e+04
# var 5:
# best............ 2.459631e+02
# mean............ 2.644408e+02
# variance........ 5.958450e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.945525e+02
# variance........ 2.620484e+03
#
# GENERATION: 6
# Lexical Fit..... 5.656021e-01  5.656021e-01  5.823705e-01  6.993742e-01  6.993742e-01  7.095096e-01  7.490089e-01  8.734552e-01  9.793631e-01  9.793631e-01  1.000000e+00  1.000000e+00
# #unique......... 133, #Total UniqueCount: 1044
# var 1:
# best............ 5.844515e+02
# mean............ 5.832945e+02
# variance........ 2.873975e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.424873e+02
# variance........ 7.706121e+03
# var 3:
# best............ 6.382410e+02
# mean............ 9.205170e+02
# variance........ 1.956746e+03
# var 4:
# best............ 7.253405e+01
# mean............ 8.907510e+01
# variance........ 9.738614e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.669553e+02
# variance........ 3.081108e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.820791e+02
# variance........ 9.081807e+03
#
# GENERATION: 7
# Lexical Fit..... 5.656021e-01  5.656021e-01  5.823705e-01  6.993742e-01  6.993742e-01  7.095096e-01  7.490089e-01  8.734552e-01  9.793631e-01  9.793631e-01  1.000000e+00  1.000000e+00
# #unique......... 132, #Total UniqueCount: 1176
# var 1:
# best............ 5.844515e+02
# mean............ 5.853192e+02
# variance........ 8.026637e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.362778e+02
# variance........ 4.623601e+03
# var 3:
# best............ 6.382410e+02
# mean............ 8.075067e+02
# variance........ 2.612427e+04
# var 4:
# best............ 7.253405e+01
# mean............ 7.728164e+01
# variance........ 4.576617e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.673135e+02
# variance........ 8.139979e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.850283e+02
# variance........ 7.959095e+03
#
# GENERATION: 8
# Lexical Fit..... 5.656021e-01  5.656021e-01  5.823705e-01  6.993742e-01  6.993742e-01  7.095096e-01  7.490089e-01  8.734552e-01  9.793631e-01  9.793631e-01  1.000000e+00  1.000000e+00
# #unique......... 103, #Total UniqueCount: 1279
# var 1:
# best............ 5.844515e+02
# mean............ 5.788542e+02
# variance........ 2.332326e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.343278e+02
# variance........ 4.431325e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.782113e+02
# variance........ 1.458246e+04
# var 4:
# best............ 7.253405e+01
# mean............ 8.428123e+01
# variance........ 4.536668e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.600199e+02
# variance........ 5.301042e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.836149e+02
# variance........ 6.620528e+03
#
# GENERATION: 9
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 105, #Total UniqueCount: 1384
# var 1:
# best............ 5.844515e+02
# mean............ 5.768071e+02
# variance........ 4.573692e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.409446e+02
# variance........ 4.918607e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.374533e+02
# variance........ 3.756997e+03
# var 4:
# best............ 9.118566e+01
# mean............ 8.649867e+01
# variance........ 5.020889e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.504280e+02
# variance........ 2.575303e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.900908e+02
# variance........ 3.931017e+03
#
# GENERATION: 10
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 138, #Total UniqueCount: 1522
# var 1:
# best............ 5.844515e+02
# mean............ 5.808133e+02
# variance........ 3.546583e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.279024e+02
# variance........ 2.236854e+02
# var 3:
# best............ 6.382410e+02
# mean............ 6.384616e+02
# variance........ 8.962271e+02
# var 4:
# best............ 9.118566e+01
# mean............ 9.635626e+01
# variance........ 6.662246e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.529804e+02
# variance........ 4.401996e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.728397e+02
# variance........ 8.610357e+03
#
# GENERATION: 11
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 147, #Total UniqueCount: 1669
# var 1:
# best............ 5.844515e+02
# mean............ 5.824840e+02
# variance........ 1.432910e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.302825e+02
# variance........ 2.672968e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.384256e+02
# variance........ 1.922551e+03
# var 4:
# best............ 9.118566e+01
# mean............ 9.829072e+01
# variance........ 4.126192e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.503168e+02
# variance........ 4.461781e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.497174e+02
# variance........ 1.297655e+04
#
# GENERATION: 12
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 136, #Total UniqueCount: 1805
# var 1:
# best............ 5.844515e+02
# mean............ 5.859761e+02
# variance........ 3.184670e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.305596e+02
# variance........ 3.165241e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.247123e+02
# variance........ 8.541387e+03
# var 4:
# best............ 9.118566e+01
# mean............ 9.561375e+01
# variance........ 3.552065e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.501724e+02
# variance........ 4.328907e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.586603e+02
# variance........ 9.064922e+03
#
# GENERATION: 13
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 138, #Total UniqueCount: 1943
# var 1:
# best............ 5.844515e+02
# mean............ 5.803714e+02
# variance........ 2.431043e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.275312e+02
# variance........ 4.133943e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.251354e+02
# variance........ 4.240860e+03
# var 4:
# best............ 9.118566e+01
# mean............ 1.057396e+02
# variance........ 9.826137e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.559584e+02
# variance........ 4.524339e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.625896e+02
# variance........ 5.783860e+03
#
# GENERATION: 14
# Lexical Fit..... 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
# #unique......... 142, #Total UniqueCount: 2085
# var 1:
# best............ 5.844515e+02
# mean............ 5.801933e+02
# variance........ 3.127552e+03
# var 2:
# best............ 3.274260e+02
# mean............ 3.343276e+02
# variance........ 2.276826e+03
# var 3:
# best............ 6.382410e+02
# mean............ 6.290782e+02
# variance........ 5.807788e+03
# var 4:
# best............ 9.118566e+01
# mean............ 1.050113e+02
# variance........ 8.470254e+03
# var 5:
# best............ 2.459631e+02
# mean............ 2.565352e+02
# variance........ 4.584366e+03
# var 6:
# best............ 9.014919e+02
# mean............ 8.531826e+02
# variance........ 9.609921e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 4 generations.
#
# Solution Lexical Fitness Value:
# 6.708139e-01  6.966496e-01  6.993742e-01  6.993742e-01  7.645204e-01  7.645204e-01  8.051121e-01  8.432932e-01  8.781816e-01  8.903178e-01  9.793631e-01  9.996333e-01
#
# Parameters at the Solution:
#
#  X[ 1] :	5.844515e+02
#  X[ 2] :	3.274260e+02
#  X[ 3] :	6.382410e+02
#  X[ 4] :	9.118566e+01
#  X[ 5] :	2.459631e+02
#  X[ 6] :	9.014919e+02
#
# Solution Found Generation 9
# Number of Generations Run 14
#
# Tue Apr 23 18:06:42 2019
# Total run time : 0 hours 0 minutes and 6 seconds
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  68
# Original number of treated obs...............  36
# Matched number of observations...............  36
# Matched number of observations  (unweighted).  36

# %%
mb1r  <- MatchBalance(Trr ~  uerate + s_black + 
    college + SenElection + factor(fips_state) + factor(year), 
    data = state.data.t4.match, match.out = moutr1, nboots=500)
# Out:
# ***** (V1) uerate *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.042917 	 	   0.042917
# mean control..........   0.058656 	 	   0.043194
# std mean diff.........    -103.31 	 	    -1.8232
#
# mean raw eQQ diff.....   0.016625 	 	  0.0016111
# med  raw eQQ diff.....      0.007 	 	      0.001
# max  raw eQQ diff.....      0.044 	 	      0.007
#
# mean eCDF diff........    0.16381 	 	   0.048354
# med  eCDF diff........    0.18229 	 	   0.027778
# max  eCDF diff........     0.3125 	 	    0.16667
#
# var ratio (Tr/Co).....    0.39685 	 	     1.0225
# T-test p-value........  0.0026117 	 	    0.84329
# KS Bootstrap p-value..      0.036 	 	      0.568
# KS Naive p-value......   0.073115 	 	    0.69937
# KS Statistic..........     0.3125 	 	    0.16667
#
#
# ***** (V2) s_black *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.089455 	 	   0.089455
# mean control..........   0.082185 	 	   0.087236
# std mean diff.........     8.8609 	 	     2.7042
#
# mean raw eQQ diff.....   0.010731 	 	  0.0079169
# med  raw eQQ diff.....  0.0089375 	 	    0.00769
# max  raw eQQ diff.....   0.089331 	 	   0.028806
#
# mean eCDF diff........   0.049595 	 	   0.041962
# med  eCDF diff........   0.041667 	 	   0.027778
# max  eCDF diff........    0.14583 	 	    0.13889
#
# var ratio (Tr/Co).....    0.96042 	 	    0.97759
# T-test p-value........    0.71943 	 	    0.67081
# KS Bootstrap p-value..      0.734 	 	      0.808
# KS Naive p-value......    0.86396 	 	    0.87818
# KS Statistic..........    0.14583 	 	    0.13889
#
#
# ***** (V3) college *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.24694 	 	    0.24694
# mean control..........    0.23011 	 	    0.24767
# std mean diff.........     26.737 	 	    -1.1548
#
# mean raw eQQ diff.....   0.014367 	 	   0.010353
# med  raw eQQ diff.....   0.010287 	 	  0.0071602
# max  raw eQQ diff.....   0.041196 	 	   0.045539
#
# mean eCDF diff........   0.070874 	 	   0.051887
# med  eCDF diff........   0.050347 	 	   0.055556
# max  eCDF diff........    0.20139 	 	    0.16667
#
# var ratio (Tr/Co).....     0.8394 	 	     1.3099
# T-test p-value........    0.29832 	 	    0.89032
# KS Bootstrap p-value..      0.392 	 	      0.632
# KS Naive p-value......    0.43212 	 	    0.69937
# KS Statistic..........    0.20139 	 	    0.16667
#
#
# ***** (V4) SenElection *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.66667 	 	    0.66667
# mean control..........    0.65625 	 	    0.69444
# std mean diff.........     2.1788 	 	    -5.8101
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0052083 	 	   0.013889
# med  eCDF diff........  0.0052083 	 	   0.013889
# max  eCDF diff........   0.010417 	 	   0.027778
#
# var ratio (Tr/Co).....    0.98157 	 	     1.0473
# T-test p-value........    0.92917 	 	    0.76452
#
#
# ***** (V5) factor(fips_state)2 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....    0.03125 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32505 	 	          1
#
#
# ***** (V6) factor(fips_state)4 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	          0
# std mean diff.........    -2.0833 	 	     16.667
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.013889
# med  eCDF diff........  0.0017361 	 	   0.013889
# max  eCDF diff........  0.0034722 	 	   0.027778
#
# var ratio (Tr/Co).....    0.88889 	 	        Inf
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V7) factor(fips_state)5 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....    0.03125 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32505 	 	          1
#
#
# ***** (V8) factor(fips_state)6 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........          0 	 	          0
# std mean diff.........     16.667 	 	     16.667
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.32417 	 	    0.31745
#
#
# ***** (V9) factor(fips_state)8 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.09375 	 	   0.083333
# std mean diff.........    -39.583 	 	    -33.333
#
# mean raw eQQ diff.....     0.0625 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.032986 	 	   0.027778
# med  eCDF diff........   0.032986 	 	   0.027778
# max  eCDF diff........   0.065972 	 	   0.055556
#
# var ratio (Tr/Co).....    0.31673 	 	    0.35354
# T-test p-value........    0.27122 	 	    0.31745
#
#
# ***** (V10) factor(fips_state)9 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083333 	 	   0.083333
# mean control..........    0.03125 	 	   0.027778
# std mean diff.........     18.581 	 	      19.82
#
# mean raw eQQ diff.....    0.03125 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.026042 	 	   0.027778
# med  eCDF diff........   0.026042 	 	   0.027778
# max  eCDF diff........   0.052083 	 	   0.055556
#
# var ratio (Tr/Co).....     2.5143 	 	     2.8286
# T-test p-value........    0.35783 	 	    0.31745
#
#
# ***** (V11) factor(fips_state)12 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	   0.083333
# std mean diff.........    -2.0833 	 	    -33.333
#
# mean raw eQQ diff.....          0 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.027778
# med  eCDF diff........  0.0017361 	 	   0.027778
# max  eCDF diff........  0.0034722 	 	   0.055556
#
# var ratio (Tr/Co).....    0.88889 	 	    0.35354
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V12) factor(fips_state)13 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	   0.083333
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.03125 	 	   0.083333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015625 	 	   0.041667
# med  eCDF diff........   0.015625 	 	   0.041667
# max  eCDF diff........    0.03125 	 	   0.083333
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32505 	 	   0.079037
#
#
# ***** (V13) factor(fips_state)16 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	          0
# std mean diff.........    -2.0833 	 	     16.667
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.013889
# med  eCDF diff........  0.0017361 	 	   0.013889
# max  eCDF diff........  0.0034722 	 	   0.027778
#
# var ratio (Tr/Co).....    0.88889 	 	        Inf
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V14) factor(fips_state)17 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.055556 	 	   0.055556
# mean control..........    0.03125 	 	    0.11111
# std mean diff.........     10.463 	 	    -23.914
#
# mean raw eQQ diff.....          0 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.012153 	 	   0.027778
# med  eCDF diff........   0.012153 	 	   0.027778
# max  eCDF diff........   0.024306 	 	   0.055556
#
# var ratio (Tr/Co).....      1.727 	 	    0.53125
# T-test p-value........    0.62686 	 	    0.41543
#
#
# ***** (V15) factor(fips_state)19 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083333 	 	   0.083333
# mean control..........     0.0625 	 	    0.11111
# std mean diff.........     7.4324 	 	    -9.9098
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.010417 	 	   0.013889
# med  eCDF diff........   0.010417 	 	   0.013889
# max  eCDF diff........   0.020833 	 	   0.027778
#
# var ratio (Tr/Co).....      1.299 	 	    0.77344
# T-test p-value........    0.74512 	 	    0.65658
#
#
# ***** (V16) factor(fips_state)20 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	          0
# std mean diff.........    -2.0833 	 	     16.667
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.013889
# med  eCDF diff........  0.0017361 	 	   0.013889
# max  eCDF diff........  0.0034722 	 	   0.027778
#
# var ratio (Tr/Co).....    0.88889 	 	        Inf
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V17) factor(fips_state)24 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........     0.0625 	 	   0.027778
# std mean diff.........    -20.833 	 	          0
#
# mean raw eQQ diff.....    0.03125 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.017361 	 	          0
# med  eCDF diff........   0.017361 	 	          0
# max  eCDF diff........   0.034722 	 	          0
#
# var ratio (Tr/Co).....    0.45926 	 	          1
# T-test p-value........    0.50383 	 	          1
#
#
# ***** (V18) factor(fips_state)25 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	          0
# std mean diff.........    -2.0833 	 	     16.667
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.013889
# med  eCDF diff........  0.0017361 	 	   0.013889
# max  eCDF diff........  0.0034722 	 	   0.027778
#
# var ratio (Tr/Co).....    0.88889 	 	        Inf
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V19) factor(fips_state)26 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........     0.0625 	 	   0.027778
# std mean diff.........    -20.833 	 	          0
#
# mean raw eQQ diff.....    0.03125 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.017361 	 	          0
# med  eCDF diff........   0.017361 	 	          0
# max  eCDF diff........   0.034722 	 	          0
#
# var ratio (Tr/Co).....    0.45926 	 	          1
# T-test p-value........    0.50383 	 	          1
#
#
# ***** (V20) factor(fips_state)27 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083333 	 	   0.083333
# mean control..........          0 	 	          0
# std mean diff.........     29.729 	 	     29.729
#
# mean raw eQQ diff.....     0.0625 	 	   0.083333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.041667 	 	   0.041667
# med  eCDF diff........   0.041667 	 	   0.041667
# max  eCDF diff........   0.083333 	 	   0.083333
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.083135 	 	   0.079037
#
#
# ***** (V21) factor(fips_state)31 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.055556 	 	   0.055556
# mean control..........    0.03125 	 	    0.16667
# std mean diff.........     10.463 	 	    -47.829
#
# mean raw eQQ diff.....          0 	 	    0.11111
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.012153 	 	   0.055556
# med  eCDF diff........   0.012153 	 	   0.055556
# max  eCDF diff........   0.024306 	 	    0.11111
#
# var ratio (Tr/Co).....      1.727 	 	    0.37778
# T-test p-value........    0.62686 	 	   0.098563
#
#
# ***** (V22) factor(fips_state)32 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........          0 	 	          0
# std mean diff.........     16.667 	 	     16.667
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.32417 	 	    0.31745
#
#
# ***** (V23) factor(fips_state)33 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	   0.027778
# std mean diff.........    -2.0833 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........  0.0017361 	 	          0
# med  eCDF diff........  0.0017361 	 	          0
# max  eCDF diff........  0.0034722 	 	          0
#
# var ratio (Tr/Co).....    0.88889 	 	          1
# T-test p-value........    0.93407 	 	          1
#
#
# ***** (V24) factor(fips_state)35 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	   0.055556
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....     0.0625 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03125 	 	   0.027778
# med  eCDF diff........    0.03125 	 	   0.027778
# max  eCDF diff........     0.0625 	 	   0.055556
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16057 	 	    0.15452
#
#
# ***** (V25) factor(fips_state)36 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........          0 	 	          0
# std mean diff.........     16.667 	 	     16.667
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.32417 	 	    0.31745
#
#
# ***** (V26) factor(fips_state)39 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	   0.027778
# std mean diff.........    -2.0833 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........  0.0017361 	 	          0
# med  eCDF diff........  0.0017361 	 	          0
# max  eCDF diff........  0.0034722 	 	          0
#
# var ratio (Tr/Co).....    0.88889 	 	          1
# T-test p-value........    0.93407 	 	          1
#
#
# ***** (V27) factor(fips_state)40 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	   0.055556
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....     0.0625 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03125 	 	   0.027778
# med  eCDF diff........    0.03125 	 	   0.027778
# max  eCDF diff........     0.0625 	 	   0.055556
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16057 	 	    0.15452
#
#
# ***** (V28) factor(fips_state)41 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.03125 	 	          0
# std mean diff.........    -2.0833 	 	     16.667
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........  0.0017361 	 	   0.013889
# med  eCDF diff........  0.0017361 	 	   0.013889
# max  eCDF diff........  0.0034722 	 	   0.027778
#
# var ratio (Tr/Co).....    0.88889 	 	        Inf
# T-test p-value........    0.93407 	 	    0.31745
#
#
# ***** (V29) factor(fips_state)44 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........          0 	 	          0
# std mean diff.........     16.667 	 	     16.667
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.32417 	 	    0.31745
#
#
# ***** (V30) factor(fips_state)45 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........          0 	 	          0
# std mean diff.........     16.667 	 	     16.667
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........    0.32417 	 	    0.31745
#
#
# ***** (V31) factor(fips_state)47 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.055556 	 	   0.055556
# mean control..........          0 	 	          0
# std mean diff.........     23.914 	 	     23.914
#
# mean raw eQQ diff.....    0.03125 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.027778 	 	   0.027778
# med  eCDF diff........   0.027778 	 	   0.027778
# max  eCDF diff........   0.055556 	 	   0.055556
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........     0.1602 	 	    0.15452
#
#
# ***** (V32) factor(fips_state)48 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	   0.027778
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.03125 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015625 	 	   0.013889
# med  eCDF diff........   0.015625 	 	   0.013889
# max  eCDF diff........    0.03125 	 	   0.027778
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32505 	 	    0.31745
#
#
# ***** (V33) factor(fips_state)50 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	   0.083333
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.03125 	 	   0.083333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015625 	 	   0.041667
# med  eCDF diff........   0.015625 	 	   0.041667
# max  eCDF diff........    0.03125 	 	   0.083333
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32505 	 	   0.079037
#
#
# ***** (V34) factor(fips_state)55 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083333 	 	   0.083333
# mean control..........          0 	 	          0
# std mean diff.........     29.729 	 	     29.729
#
# mean raw eQQ diff.....     0.0625 	 	   0.083333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.041667 	 	   0.041667
# med  eCDF diff........   0.041667 	 	   0.041667
# max  eCDF diff........   0.083333 	 	   0.083333
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.083135 	 	   0.079037
#
#
# ***** (V35) factor(fips_state)56 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....     0.0625 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.03125 	 	          0
# med  eCDF diff........    0.03125 	 	          0
# max  eCDF diff........     0.0625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.16057 	 	          1
#
#
# ***** (V36) factor(year)1990 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11111 	 	    0.11111
# mean control..........    0.03125 	 	   0.027778
# std mean diff.........     25.056 	 	     26.146
#
# mean raw eQQ diff.....     0.0625 	 	   0.083333
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.039931 	 	   0.041667
# med  eCDF diff........   0.039931 	 	   0.041667
# max  eCDF diff........   0.079861 	 	   0.083333
#
# var ratio (Tr/Co).....     3.2508 	 	     3.6571
# T-test p-value........    0.20038 	 	    0.17741
#
#
# ***** (V37) factor(year)1994 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11111 	 	    0.11111
# mean control..........     0.0625 	 	    0.16667
# std mean diff.........     15.252 	 	     -17.43
#
# mean raw eQQ diff.....    0.03125 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024306 	 	   0.027778
# med  eCDF diff........   0.024306 	 	   0.027778
# max  eCDF diff........   0.048611 	 	   0.055556
#
# var ratio (Tr/Co).....     1.6796 	 	    0.71111
# T-test p-value........    0.48138 	 	    0.31745
#
#
# ***** (V38) factor(year)1998 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.33333 	 	    0.33333
# mean control..........      0.125 	 	    0.22222
# std mean diff.........     43.576 	 	     23.241
#
# mean raw eQQ diff.....     0.1875 	 	    0.11111
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.10417 	 	   0.055556
# med  eCDF diff........    0.10417 	 	   0.055556
# max  eCDF diff........    0.20833 	 	    0.11111
#
# var ratio (Tr/Co).....     2.0245 	 	     1.2857
# T-test p-value........   0.040097 	 	   0.098563
#
#
# ***** (V39) factor(year)2002 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.027778 	 	   0.027778
# mean control..........    0.09375 	 	   0.083333
# std mean diff.........    -39.583 	 	    -33.333
#
# mean raw eQQ diff.....     0.0625 	 	   0.055556
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.032986 	 	   0.027778
# med  eCDF diff........   0.032986 	 	   0.027778
# max  eCDF diff........   0.065972 	 	   0.055556
#
# var ratio (Tr/Co).....    0.31673 	 	    0.35354
# T-test p-value........    0.27122 	 	    0.31745
#
#
# ***** (V40) factor(year)2006 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.27778 	 	    0.27778
# mean control..........       0.25 	 	    0.30556
# std mean diff.........      6.115 	 	     -6.115
#
# mean raw eQQ diff.....          0 	 	   0.027778
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........   0.013889 	 	   0.013889
# med  eCDF diff........   0.013889 	 	   0.013889
# max  eCDF diff........   0.027778 	 	   0.027778
#
# var ratio (Tr/Co).....     1.0661 	 	    0.94545
# T-test p-value........    0.79881 	 	    0.65658
#
#
# Before Matching Minimum p.value: 0.0026117
# Variable Name(s): uerate  Number(s): 1
#
# After Matching Minimum p.value: 0.079037
# Variable Name(s): factor(fips_state)13 factor(fips_state)27 factor(fips_state)50 factor(fips_state)55  Number(s): 12 20 33 34

# %%
# checking effect

mout1ry = Match(Tr = Trr, X = Xr, Y= state.data.t4.match$vep, Weight.matrix=genoutr1)
summary(mout1y)
# Out:
# Estimate...  0.028824
# AI SE......  0.024583
# T-stat.....  1.1725
# p.val......  0.241
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  17
# Matched number of observations  (unweighted).  17

# %% [markdown]
# # GenMatch Rep Inc x Unemployment

# %%
# Gen Match
library('Matching')
library('rgenoud')

TrRe = ifelse(state.data.t4.match$incparty =='R', 1, 0)*state.data.t4.match$treat

XRe = cbind(state.data.t4.match$s_black, state.data.t4.match$college, 
          state.data.t4.match$SenElection, factor(state.data.t4.match$fips_state),
          factor(state.data.t4.match$year))


# X = cbind(state.data.t4.match$year,state.data.t4.match$fips_state,
#       state.data.t4.match$s_black, state.data.t4.match$SenElection,
#       state.data.t4.match$presyear, state.data.t4.match$college,
#       state.data.t4.match$college_diff, state.data.t4.match$pci_0000,
#       state.data.t4.match$prior_ue, state.data.t4.match$partyspending,
#       state.data.t4.match$priorue_diff, state.data.t4.match$spending_diff,
#       state.data.t4.match$share_open, state.data.t4.match$share_qual_out2,
#       state.data.t4.match$open_all_share, state.data.t4.match$quality_share_new,
#       state.data.t4.match$outparty_spend, state.data.t4.match$share_open_diff,
#       state.data.t4.match$open_all_share_diff, state.data.t4.match$share_qual_out2_diff,
#       state.data.t4.match$quality_share_diff, state.data.t4.match$outparty_spend_diff,
#       state.data.t4.match$s_black_diff, state.data.t4.match$pci0000_diff,
#       state.data.t4.match$senelec_diff, state.data.t4.match$incparty,
#       state.data.t4.match$GubElection, state.data.t4.match$vep,
#       state.data.t4.match$uerate)

genoutRe = GenMatch(Tr = TrRe, X = XRe,pop.size=200,max.generations=25)
moutRe = Match(Tr = TrRe, X = XRe, Weight.matrix=genoutRe)
summary(moutRe)
# Out:
# Tue Apr 23 18:12:19 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	22
# 	(2) Uniform Mutation.................. 	25
# 	(3) Boundary Mutation................. 	25
# 	(4) Non-Uniform Mutation.............. 	25
# 	(5) Polytope Crossover................ 	25
# 	(6) Simple Crossover.................. 	26
# 	(7) Whole Non-Uniform Mutation........ 	25
# 	(8) Heuristic Crossover............... 	26
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 25
# Maximum Nonchanging Generations: 4
# Population size       : 200
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 200, #Total UniqueCount: 200
# var 1:
# best............ 2.885119e+01
# mean............ 5.203624e+02
# variance........ 9.104244e+04
# var 2:
# best............ 2.445518e+02
# mean............ 4.920168e+02
# variance........ 8.499017e+04
# var 3:
# best............ 1.708225e+02
# mean............ 5.006643e+02
# variance........ 7.856537e+04
# var 4:
# best............ 7.123161e+02
# mean............ 5.281854e+02
# variance........ 8.018250e+04
# var 5:
# best............ 8.778063e+02
# mean............ 4.809414e+02
# variance........ 8.623876e+04
#
# GENERATION: 1
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 152, #Total UniqueCount: 352
# var 1:
# best............ 2.885119e+01
# mean............ 1.327901e+02
# variance........ 4.570918e+04
# var 2:
# best............ 2.445518e+02
# mean............ 2.551694e+02
# variance........ 3.338426e+04
# var 3:
# best............ 1.708225e+02
# mean............ 4.206564e+02
# variance........ 6.867989e+04
# var 4:
# best............ 7.123161e+02
# mean............ 6.912351e+02
# variance........ 6.669876e+04
# var 5:
# best............ 8.778063e+02
# mean............ 7.341133e+02
# variance........ 6.059834e+04
#
# GENERATION: 2
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 139, #Total UniqueCount: 491
# var 1:
# best............ 2.885119e+01
# mean............ 5.129958e+01
# variance........ 9.241682e+03
# var 2:
# best............ 2.445518e+02
# mean............ 2.815604e+02
# variance........ 9.276711e+03
# var 3:
# best............ 1.708225e+02
# mean............ 3.494466e+02
# variance........ 7.296008e+04
# var 4:
# best............ 7.123161e+02
# mean............ 7.747586e+02
# variance........ 2.203741e+04
# var 5:
# best............ 8.778063e+02
# mean............ 8.419878e+02
# variance........ 1.169003e+04
#
# GENERATION: 3
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 137, #Total UniqueCount: 628
# var 1:
# best............ 2.885119e+01
# mean............ 5.118517e+01
# variance........ 1.261634e+04
# var 2:
# best............ 2.445518e+02
# mean............ 3.017584e+02
# variance........ 1.139882e+04
# var 3:
# best............ 1.708225e+02
# mean............ 3.963087e+02
# variance........ 7.303993e+04
# var 4:
# best............ 7.123161e+02
# mean............ 7.959664e+02
# variance........ 2.189454e+04
# var 5:
# best............ 8.778063e+02
# mean............ 8.498998e+02
# variance........ 7.489464e+03
#
# GENERATION: 4
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 130, #Total UniqueCount: 758
# var 1:
# best............ 2.885119e+01
# mean............ 4.813419e+01
# variance........ 6.356548e+03
# var 2:
# best............ 2.445518e+02
# mean............ 2.801686e+02
# variance........ 5.762601e+03
# var 3:
# best............ 1.708225e+02
# mean............ 3.775077e+02
# variance........ 7.375624e+04
# var 4:
# best............ 7.123161e+02
# mean............ 7.940901e+02
# variance........ 2.031574e+04
# var 5:
# best............ 8.778063e+02
# mean............ 8.501090e+02
# variance........ 7.090393e+03
#
# GENERATION: 5
# Lexical Fit..... 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# #unique......... 136, #Total UniqueCount: 894
# var 1:
# best............ 2.885119e+01
# mean............ 4.308169e+01
# variance........ 7.648178e+03
# var 2:
# best............ 2.445518e+02
# mean............ 2.860311e+02
# variance........ 7.245367e+03
# var 3:
# best............ 1.708225e+02
# mean............ 4.095500e+02
# variance........ 8.260870e+04
# var 4:
# best............ 7.123161e+02
# mean............ 7.840574e+02
# variance........ 3.410527e+04
# var 5:
# best............ 8.778063e+02
# mean............ 8.550311e+02
# variance........ 6.245764e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 4 generations.
#
# Solution Lexical Fitness Value:
# 4.813669e-01  7.259774e-01  7.714286e-01  7.714286e-01  8.806582e-01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
# Parameters at the Solution:
#
#  X[ 1] :	2.885119e+01
#  X[ 2] :	2.445518e+02
#  X[ 3] :	1.708225e+02
#  X[ 4] :	7.123161e+02
#  X[ 5] :	8.778063e+02
#
# Solution Found Generation 1
# Number of Generations Run 5
#
# Tue Apr 23 18:12:20 2019
# Total run time : 0 hours 0 minutes and 1 seconds
#
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  68
# Original number of treated obs...............  4
# Matched number of observations...............  4
# Matched number of observations  (unweighted).  4

# %%
mbRe  <- MatchBalance(TrRe ~ s_black + 
    college + SenElection + factor(fips_state) + factor(year), 
    data = state.data.t4.match, match.out = moutRe, nboots=500)
# Out:
# ***** (V1) s_black *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.098215 	 	   0.098215
# mean control..........   0.085272 	 	   0.065704
# std mean diff.........     19.275 	 	     48.421
#
# mean raw eQQ diff.....   0.061956 	 	   0.032511
# med  raw eQQ diff.....   0.047775 	 	   0.035935
# max  raw eQQ diff.....    0.14037 	 	   0.046822
#
# mean eCDF diff........    0.13802 	 	     0.1875
# med  eCDF diff........    0.11719 	 	       0.25
# max  eCDF diff........    0.35938 	 	        0.5
#
# var ratio (Tr/Co).....    0.64596 	 	     1.5597
# T-test p-value........    0.73336 	 	    0.48137
# KS Bootstrap p-value..       0.59 	 	      0.608
# KS Naive p-value......    0.71574 	 	    0.77143
# KS Statistic..........    0.35938 	 	        0.5
#
#
# ***** (V2) college *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.19698 	 	    0.19698
# mean control..........    0.24165 	 	    0.20125
# std mean diff.........    -72.257 	 	     -6.913
#
# mean raw eQQ diff.....   0.045311 	 	   0.040526
# med  raw eQQ diff.....   0.032909 	 	   0.036252
# max  raw eQQ diff.....    0.11237 	 	   0.058646
#
# mean eCDF diff........    0.18015 	 	     0.1875
# med  eCDF diff........    0.17969 	 	       0.25
# max  eCDF diff........    0.40625 	 	        0.5
#
# var ratio (Tr/Co).....    0.88856 	 	    0.56356
# T-test p-value........    0.24589 	 	    0.88066
# KS Bootstrap p-value..      0.446 	 	      0.616
# KS Naive p-value......    0.47129 	 	    0.77143
# KS Statistic..........    0.40625 	 	        0.5
#
#
# ***** (V3) SenElection *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.75 	 	       0.75
# mean control..........    0.65625 	 	       0.75
# std mean diff.........      18.75 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.046875 	 	          0
# med  eCDF diff........   0.046875 	 	          0
# max  eCDF diff........    0.09375 	 	          0
#
# var ratio (Tr/Co).....     1.0909 	 	          1
# T-test p-value........    0.73714 	 	          1
#
#
# ***** (V4) factor(fips_state)2 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V5) factor(fips_state)4 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V6) factor(fips_state)5 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V7) factor(fips_state)6 *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.25 	 	       0.25
# mean control..........          0 	 	          0
# std mean diff.........         50 	 	         50
#
# mean raw eQQ diff.....       0.25 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........      0.125 	 	      0.125
# med  eCDF diff........      0.125 	 	      0.125
# max  eCDF diff........       0.25 	 	       0.25
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........      0.391 	 	    0.33184
#
#
# ***** (V8) factor(fips_state)8 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	       0.25
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....       0.25 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03125 	 	      0.125
# med  eCDF diff........    0.03125 	 	      0.125
# max  eCDF diff........     0.0625 	 	       0.25
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.044593 	 	    0.33184
#
#
# ***** (V9) factor(fips_state)9 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.03125 	 	          0
# med  eCDF diff........    0.03125 	 	          0
# max  eCDF diff........     0.0625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.044593 	 	          1
#
#
# ***** (V10) factor(fips_state)12 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V11) factor(fips_state)13 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V12) factor(fips_state)16 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	       0.25
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....       0.25 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015625 	 	      0.125
# med  eCDF diff........   0.015625 	 	      0.125
# max  eCDF diff........    0.03125 	 	       0.25
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.15893 	 	    0.33184
#
#
# ***** (V13) factor(fips_state)17 *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.25 	 	       0.25
# mean control..........    0.03125 	 	          0
# std mean diff.........      43.75 	 	         50
#
# mean raw eQQ diff.....          0 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........    0.10938 	 	      0.125
# med  eCDF diff........    0.10938 	 	      0.125
# max  eCDF diff........    0.21875 	 	       0.25
#
# var ratio (Tr/Co).....      8.129 	 	        Inf
# T-test p-value........    0.44665 	 	    0.33184
#
#
# ***** (V14) factor(fips_state)19 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.078125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.039062 	 	          0
# med  eCDF diff........   0.039062 	 	          0
# max  eCDF diff........   0.078125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.02414 	 	          1
#
#
# ***** (V15) factor(fips_state)20 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V16) factor(fips_state)24 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.046875 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.023438 	 	          0
# med  eCDF diff........   0.023438 	 	          0
# max  eCDF diff........   0.046875 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083225 	 	          1
#
#
# ***** (V17) factor(fips_state)25 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V18) factor(fips_state)26 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.046875 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.023438 	 	          0
# med  eCDF diff........   0.023438 	 	          0
# max  eCDF diff........   0.046875 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083225 	 	          1
#
#
# ***** (V19) factor(fips_state)27 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.046875 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.023438 	 	          0
# med  eCDF diff........   0.023438 	 	          0
# max  eCDF diff........   0.046875 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083225 	 	          1
#
#
# ***** (V20) factor(fips_state)31 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.046875 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.023438 	 	          0
# med  eCDF diff........   0.023438 	 	          0
# max  eCDF diff........   0.046875 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083225 	 	          1
#
#
# ***** (V21) factor(fips_state)32 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V22) factor(fips_state)33 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V23) factor(fips_state)35 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V24) factor(fips_state)36 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V25) factor(fips_state)39 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	       0.25
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....       0.25 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015625 	 	      0.125
# med  eCDF diff........   0.015625 	 	      0.125
# max  eCDF diff........    0.03125 	 	       0.25
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.15893 	 	    0.33184
#
#
# ***** (V26) factor(fips_state)40 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V27) factor(fips_state)41 *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.25 	 	       0.25
# mean control..........   0.015625 	 	          0
# std mean diff.........     46.875 	 	         50
#
# mean raw eQQ diff.....          0 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........    0.11719 	 	      0.125
# med  eCDF diff........    0.11719 	 	      0.125
# max  eCDF diff........    0.23438 	 	       0.25
#
# var ratio (Tr/Co).....         16 	 	        Inf
# T-test p-value........    0.41798 	 	    0.33184
#
#
# ***** (V28) factor(fips_state)44 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V29) factor(fips_state)45 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V30) factor(fips_state)47 *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.25 	 	       0.25
# mean control..........   0.015625 	 	          0
# std mean diff.........     46.875 	 	         50
#
# mean raw eQQ diff.....          0 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........    0.11719 	 	      0.125
# med  eCDF diff........    0.11719 	 	      0.125
# max  eCDF diff........    0.23438 	 	       0.25
#
# var ratio (Tr/Co).....         16 	 	        Inf
# T-test p-value........    0.41798 	 	    0.33184
#
#
# ***** (V31) factor(fips_state)48 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	       0.25
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....       0.25 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0078125 	 	      0.125
# med  eCDF diff........  0.0078125 	 	      0.125
# max  eCDF diff........   0.015625 	 	       0.25
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.32114 	 	    0.33184
#
#
# ***** (V32) factor(fips_state)50 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.015625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0078125 	 	          0
# med  eCDF diff........  0.0078125 	 	          0
# max  eCDF diff........   0.015625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.32114 	 	          1
#
#
# ***** (V33) factor(fips_state)55 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.046875 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.023438 	 	          0
# med  eCDF diff........   0.023438 	 	          0
# max  eCDF diff........   0.046875 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.083225 	 	          1
#
#
# ***** (V34) factor(fips_state)56 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.03125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.015625 	 	          0
# med  eCDF diff........   0.015625 	 	          0
# max  eCDF diff........    0.03125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.15893 	 	          1
#
#
# ***** (V35) factor(year)1990 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.078125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.039062 	 	          0
# med  eCDF diff........   0.039062 	 	          0
# max  eCDF diff........   0.078125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........    0.02414 	 	          1
#
#
# ***** (V36) factor(year)1994 *****
#                        Before Matching 	 	 After Matching
# mean treatment........       0.25 	 	       0.25
# mean control..........   0.078125 	 	       0.25
# std mean diff.........     34.375 	 	          0
#
# mean raw eQQ diff.....          0 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          0
#
# mean eCDF diff........   0.085938 	 	          0
# med  eCDF diff........   0.085938 	 	          0
# max  eCDF diff........    0.17188 	 	          0
#
# var ratio (Tr/Co).....     3.4169 	 	          1
# T-test p-value........    0.54296 	 	          1
#
#
# ***** (V37) factor(year)1998 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........       0.25 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........      0.125 	 	          0
# med  eCDF diff........      0.125 	 	          0
# max  eCDF diff........       0.25 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........ 2.2275e-05 	 	          1
#
#
# ***** (V38) factor(year)2002 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........     0.0625 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.03125 	 	          0
# med  eCDF diff........    0.03125 	 	          0
# max  eCDF diff........     0.0625 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........   0.044593 	 	          1
#
#
# ***** (V39) factor(year)2006 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.28125 	 	          0
# std mean diff.........       -Inf 	 	          0
#
# mean raw eQQ diff.....       0.25 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........    0.14062 	 	          0
# med  eCDF diff........    0.14062 	 	          0
# max  eCDF diff........    0.28125 	 	          0
#
# var ratio (Tr/Co).....          0 	 	        NaN
# T-test p-value........ 5.5273e-06 	 	          1
#
#
# Before Matching Minimum p.value: 5.5273e-06
# Variable Name(s): factor(year)2006  Number(s): 39
#
# After Matching Minimum p.value: 0.33184
# Variable Name(s): factor(fips_state)6 factor(fips_state)8 factor(fips_state)16 factor(fips_state)17 factor(fips_state)39 factor(fips_state)41 factor(fips_state)47 factor(fips_state)48  Number(s): 7 8 12 13 25 27 30 31

# %%
# checking effect

moutRey = Match(Tr = TrRe, X = XRe, Y= state.data.t4.match$vep, Weight.matrix=genoutRe)
summary(mout1y)
# Out:
# Estimate...  0.028824
# AI SE......  0.024583
# T-stat.....  1.1725
# p.val......  0.241
#
# Original number of observations..............  68
# Original number of treated obs...............  17
# Matched number of observations...............  17
# Matched number of observations  (unweighted).  17

# %% [markdown]
# # Genmatch Black - tbd

# %%
# Gen Match
library('Matching')
library('rgenoud')

# get quantiles on black
b_q = quantile(state.data.t4$s_black,c(.25,.75))

# make new dataset w control  beng <= 25% black
# and treat being >= 75% black
state.data.t4.Bmatch = state.data.t4[state.data.t4$s_black <= b_q[1] | state.data.t4$s_black >= b_q[2],]
state.data.t4.Bmatch$treat = ifelse(state.data.t4.Bmatch$s_black >= b_q[2], 1, 0)
# remove NAs
state.data.t4.Bmatch <- state.data.t4.Bmatch[complete.cases(state.data.t4.Bmatch), ]
which(is.na(state.data.t4.match) == TRUE)

TrB = state.data.t4.Bmatch$treat

XB = cbind(state.data.t4.Bmatch$incparty,state.data.t4.Bmatch$uerate, state.data.t4.Bmatch$college, 
          state.data.t4.Bmatch$SenElection, factor(state.data.t4.Bmatch$fips_state),
          factor(state.data.t4.Bmatch$year))


# X = cbind(state.data.t4.match$year,state.data.t4.match$fips_state,
#       state.data.t4.match$s_black, state.data.t4.match$SenElection,
#       state.data.t4.match$presyear, state.data.t4.match$college,
#       state.data.t4.match$college_diff, state.data.t4.match$pci_0000,
#       state.data.t4.match$prior_ue, state.data.t4.match$partyspending,
#       state.data.t4.match$priorue_diff, state.data.t4.match$spending_diff,
#       state.data.t4.match$share_open, state.data.t4.match$share_qual_out2,
#       state.data.t4.match$open_all_share, state.data.t4.match$quality_share_new,
#       state.data.t4.match$outparty_spend, state.data.t4.match$share_open_diff,
#       state.data.t4.match$open_all_share_diff, state.data.t4.match$share_qual_out2_diff,
#       state.data.t4.match$quality_share_diff, state.data.t4.match$outparty_spend_diff,
#       state.data.t4.match$s_black_diff, state.data.t4.match$pci0000_diff,
#       state.data.t4.match$senelec_diff, state.data.t4.match$incparty,
#       state.data.t4.match$GubElection, state.data.t4.match$vep,
#       state.data.t4.match$uerate)

genoutB = GenMatch(Tr = TrB, X = XB,pop.size=200,max.generations=25)
moutB = Match(Tr = TrB, X = XB, Weight.matrix=genoutB)
summary(moutB)
# Out:
# integer(0)
# Tue Apr 23 18:36:26 2019
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	22
# 	(2) Uniform Mutation.................. 	25
# 	(3) Boundary Mutation................. 	25
# 	(4) Non-Uniform Mutation.............. 	25
# 	(5) Polytope Crossover................ 	25
# 	(6) Simple Crossover.................. 	26
# 	(7) Whole Non-Uniform Mutation........ 	25
# 	(8) Heuristic Crossover............... 	26
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 25
# Maximum Nonchanging Generations: 4
# Population size       : 200
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Maximization Problem.
# GENERATION: 0 (initializing the population)
# Lexical Fit..... 3.527645e-04  1.147520e-02  1.968731e-02  1.982331e-02  2.108307e-02  3.173694e-01  3.173694e-01  4.646819e-01  9.047977e-01  9.442006e-01  1.000000e+00  1.000000e+00
# #unique......... 200, #Total UniqueCount: 200
# var 1:
# best............ 6.091775e+02
# mean............ 5.195545e+02
# variance........ 8.891791e+04
# var 2:
# best............ 1.296359e+02
# mean............ 5.030330e+02
# variance........ 8.714340e+04
# var 3:
# best............ 7.431464e+02
# mean............ 4.970541e+02
# variance........ 8.513974e+04
# var 4:
# best............ 9.794866e+01
# mean............ 4.854299e+02
# variance........ 8.507262e+04
# var 5:
# best............ 1.947967e+02
# mean............ 4.989728e+02
# variance........ 8.841524e+04
# var 6:
# best............ 8.045616e+02
# mean............ 4.775595e+02
# variance........ 7.587701e+04
#
# GENERATION: 1
# Lexical Fit..... 3.527645e-04  1.331778e-02  1.365491e-02  2.068632e-02  2.747923e-02  3.173694e-01  3.173694e-01  5.282385e-01  5.282385e-01  6.171950e-01  7.740879e-01  9.134963e-01
# #unique......... 150, #Total UniqueCount: 350
# var 1:
# best............ 4.905225e+02
# mean............ 6.932096e+02
# variance........ 3.026576e+04
# var 2:
# best............ 1.185563e+02
# mean............ 1.839424e+02
# variance........ 1.952046e+04
# var 3:
# best............ 9.593619e+02
# mean............ 7.248207e+02
# variance........ 3.802881e+04
# var 4:
# best............ 9.423521e+01
# mean............ 2.744137e+02
# variance........ 5.928780e+04
# var 5:
# best............ 2.107563e+02
# mean............ 2.813491e+02
# variance........ 3.977567e+04
# var 6:
# best............ 6.533006e+02
# mean............ 7.209117e+02
# variance........ 3.270622e+04
#
# GENERATION: 2
# Lexical Fit..... 3.527645e-04  1.872847e-02  1.968731e-02  2.068632e-02  3.281628e-02  3.173694e-01  3.173694e-01  4.646819e-01  7.638182e-01  9.047977e-01  1.000000e+00  1.000000e+00
# #unique......... 144, #Total UniqueCount: 494
# var 1:
# best............ 7.552393e+02
# mean............ 5.752008e+02
# variance........ 1.535346e+04
# var 2:
# best............ 1.296359e+02
# mean............ 1.512844e+02
# variance........ 8.916451e+03
# var 3:
# best............ 8.883002e+02
# mean............ 8.558849e+02
# variance........ 1.573630e+04
# var 4:
# best............ 9.794866e+01
# mean............ 1.323538e+02
# variance........ 1.041705e+04
# var 5:
# best............ 1.947967e+02
# mean............ 2.336295e+02
# variance........ 1.118050e+04
# var 6:
# best............ 8.045616e+02
# mean............ 7.202797e+02
# variance........ 1.508550e+04
#
# GENERATION: 3
# Lexical Fit..... 3.527645e-04  1.872847e-02  2.068632e-02  3.203482e-02  3.404479e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.843077e-01  9.047977e-01  1.000000e+00  1.000000e+00
# #unique......... 147, #Total UniqueCount: 641
# var 1:
# best............ 7.166057e+02
# mean............ 6.834423e+02
# variance........ 1.343740e+04
# var 2:
# best............ 1.171934e+02
# mean............ 1.379537e+02
# variance........ 4.140025e+03
# var 3:
# best............ 8.677798e+02
# mean............ 8.725838e+02
# variance........ 1.039164e+04
# var 4:
# best............ 1.340974e+02
# mean............ 1.093435e+02
# variance........ 3.091608e+03
# var 5:
# best............ 1.658164e+02
# mean............ 2.183823e+02
# variance........ 9.593829e+03
# var 6:
# best............ 6.333847e+02
# mean............ 7.724111e+02
# variance........ 4.320844e+03
#
# GENERATION: 4
# Lexical Fit..... 3.527645e-04  1.872847e-02  2.388928e-02  3.598274e-02  4.422670e-02  4.613447e-01  4.646819e-01  4.805285e-01  4.805285e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 144, #Total UniqueCount: 785
# var 1:
# best............ 7.497837e+02
# mean............ 7.287295e+02
# variance........ 3.626820e+03
# var 2:
# best............ 1.134040e+02
# mean............ 1.417249e+02
# variance........ 4.644882e+03
# var 3:
# best............ 8.722697e+02
# mean............ 8.618219e+02
# variance........ 5.448517e+03
# var 4:
# best............ 1.337256e+02
# mean............ 1.302775e+02
# variance........ 4.728493e+03
# var 5:
# best............ 1.800688e+02
# mean............ 1.972163e+02
# variance........ 6.447907e+03
# var 6:
# best............ 5.422729e+02
# mean............ 7.252932e+02
# variance........ 1.130540e+04
#
# GENERATION: 5
# Lexical Fit..... 3.527645e-04  1.872847e-02  2.388928e-02  3.598274e-02  4.422670e-02  4.613447e-01  4.646819e-01  4.805285e-01  4.805285e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 142, #Total UniqueCount: 927
# var 1:
# best............ 7.497837e+02
# mean............ 7.237297e+02
# variance........ 4.980556e+03
# var 2:
# best............ 1.134040e+02
# mean............ 1.316686e+02
# variance........ 7.510881e+03
# var 3:
# best............ 8.722697e+02
# mean............ 8.477026e+02
# variance........ 8.253646e+03
# var 4:
# best............ 1.337256e+02
# mean............ 1.394279e+02
# variance........ 1.824856e+03
# var 5:
# best............ 1.800688e+02
# mean............ 1.894182e+02
# variance........ 5.650269e+03
# var 6:
# best............ 5.422729e+02
# mean............ 5.994958e+02
# variance........ 1.078164e+04
#
# GENERATION: 6
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 150, #Total UniqueCount: 1077
# var 1:
# best............ 7.491749e+02
# mean............ 7.397410e+02
# variance........ 7.162349e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.251880e+02
# variance........ 4.708029e+03
# var 3:
# best............ 8.642447e+02
# mean............ 8.521782e+02
# variance........ 7.095978e+03
# var 4:
# best............ 1.446990e+02
# mean............ 1.436796e+02
# variance........ 4.522406e+03
# var 5:
# best............ 2.247534e+02
# mean............ 1.899363e+02
# variance........ 4.403402e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.523845e+02
# variance........ 5.188824e+03
#
# GENERATION: 7
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 145, #Total UniqueCount: 1222
# var 1:
# best............ 7.491749e+02
# mean............ 7.311299e+02
# variance........ 9.606586e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.345092e+02
# variance........ 6.193807e+03
# var 3:
# best............ 8.642447e+02
# mean............ 8.543708e+02
# variance........ 3.949602e+03
# var 4:
# best............ 1.446990e+02
# mean............ 1.471368e+02
# variance........ 5.155131e+03
# var 5:
# best............ 2.247534e+02
# mean............ 2.178937e+02
# variance........ 6.284546e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.445990e+02
# variance........ 3.126645e+03
#
# GENERATION: 8
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 149, #Total UniqueCount: 1371
# var 1:
# best............ 7.491749e+02
# mean............ 7.366404e+02
# variance........ 5.113644e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.326347e+02
# variance........ 4.623909e+03
# var 3:
# best............ 8.642447e+02
# mean............ 8.484834e+02
# variance........ 4.426597e+03
# var 4:
# best............ 1.446990e+02
# mean............ 1.604691e+02
# variance........ 8.771042e+03
# var 5:
# best............ 2.247534e+02
# mean............ 2.273975e+02
# variance........ 4.746320e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.472755e+02
# variance........ 2.879932e+03
#
# GENERATION: 9
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 149, #Total UniqueCount: 1520
# var 1:
# best............ 7.491749e+02
# mean............ 7.345811e+02
# variance........ 5.081727e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.373775e+02
# variance........ 5.165283e+03
# var 3:
# best............ 8.642447e+02
# mean............ 8.375815e+02
# variance........ 1.186023e+04
# var 4:
# best............ 1.446990e+02
# mean............ 1.577434e+02
# variance........ 6.612472e+03
# var 5:
# best............ 2.247534e+02
# mean............ 2.288396e+02
# variance........ 5.982748e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.356207e+02
# variance........ 4.261397e+03
#
# GENERATION: 10
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 142, #Total UniqueCount: 1662
# var 1:
# best............ 7.491749e+02
# mean............ 7.450544e+02
# variance........ 2.022282e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.272868e+02
# variance........ 8.160613e+02
# var 3:
# best............ 8.642447e+02
# mean............ 8.508111e+02
# variance........ 3.326224e+03
# var 4:
# best............ 1.446990e+02
# mean............ 1.557499e+02
# variance........ 8.462633e+03
# var 5:
# best............ 2.247534e+02
# mean............ 2.173516e+02
# variance........ 1.092793e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.478345e+02
# variance........ 3.236712e+03
#
# GENERATION: 11
# Lexical Fit..... 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
# #unique......... 149, #Total UniqueCount: 1811
# var 1:
# best............ 7.491749e+02
# mean............ 7.433591e+02
# variance........ 1.947815e+03
# var 2:
# best............ 1.250597e+02
# mean............ 1.329812e+02
# variance........ 6.217944e+03
# var 3:
# best............ 8.642447e+02
# mean............ 8.566977e+02
# variance........ 8.638350e+02
# var 4:
# best............ 1.446990e+02
# mean............ 1.508764e+02
# variance........ 5.292044e+03
# var 5:
# best............ 2.247534e+02
# mean............ 2.336224e+02
# variance........ 6.873277e+03
# var 6:
# best............ 5.464037e+02
# mean............ 5.455266e+02
# variance........ 1.311929e+03
#
# 'wait.generations' limit reached.
# No significant improvement in 4 generations.
#
# Solution Lexical Fitness Value:
# 3.527645e-04  2.068632e-02  2.108307e-02  2.388928e-02  2.701366e-02  4.646819e-01  4.805285e-01  4.805285e-01  6.226328e-01  7.740879e-01  1.000000e+00  1.000000e+00
#
# Parameters at the Solution:
#
#  X[ 1] :	7.491749e+02
#  X[ 2] :	1.250597e+02
#  X[ 3] :	8.642447e+02
#  X[ 4] :	1.446990e+02
#  X[ 5] :	2.247534e+02
#  X[ 6] :	5.464037e+02
#
# Solution Found Generation 6
# Number of Generations Run 11
#
# Tue Apr 23 18:36:31 2019
# Total run time : 0 hours 0 minutes and 5 seconds
# Estimate...  0
# SE.........  0
# T-stat.....  NaN
# p.val......  NA
#
# Original number of observations..............  83
# Original number of treated obs...............  56
# Matched number of observations...............  56
# Matched number of observations  (unweighted).  56

# %%
mbB  <- MatchBalance(TrB ~ incparty + uerate +
    college + SenElection + factor(fips_state) + factor(year), 
    data = state.data.t4.Bmatch, match.out = moutB, nboots=500)
# Out:
# ***** (V1) incpartyR *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.51786 	 	    0.51786
# mean control..........    0.40741 	 	    0.51786
# std mean diff.........     21.906 	 	          0
#
# mean raw eQQ diff.....    0.11111 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........   0.055225 	 	          0
# med  eCDF diff........   0.055225 	 	          0
# max  eCDF diff........    0.11045 	 	          0
#
# var ratio (Tr/Co).....      1.014 	 	          1
# T-test p-value........    0.35191 	 	          1
#
#
# ***** (V2) uerate *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.055143 	 	   0.055143
# mean control..........   0.054407 	 	   0.051107
# std mean diff.........     6.0916 	 	     33.427
#
# mean raw eQQ diff.....      0.005 	 	  0.0065357
# med  raw eQQ diff.....      0.004 	 	      0.005
# max  raw eQQ diff.....      0.015 	 	      0.012
#
# mean eCDF diff........   0.076357 	 	    0.11372
# med  eCDF diff........   0.075397 	 	   0.089286
# max  eCDF diff........    0.16865 	 	    0.28571
#
# var ratio (Tr/Co).....    0.45845 	 	    0.54546
# T-test p-value........    0.84725 	 	   0.027014
# KS Bootstrap p-value..      0.482 	 	      0.008
# KS Naive p-value......    0.67803 	 	   0.020686
# KS Statistic..........    0.16865 	 	    0.28571
#
#
# ***** (V3) college *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.21582 	 	    0.21582
# mean control..........    0.20746 	 	    0.21386
# std mean diff.........     13.547 	 	     3.1697
#
# mean raw eQQ diff.....   0.013374 	 	   0.013027
# med  raw eQQ diff.....   0.010332 	 	   0.010693
# max  raw eQQ diff.....   0.036622 	 	   0.045595
#
# mean eCDF diff........   0.065213 	 	   0.056962
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.16534 	 	    0.16071
#
# var ratio (Tr/Co).....     1.2147 	 	     1.5052
# T-test p-value........    0.54031 	 	    0.62263
# KS Bootstrap p-value..      0.592 	 	      0.422
# KS Naive p-value......    0.63004 	 	    0.46468
# KS Statistic..........    0.16534 	 	    0.16071
#
#
# ***** (V4) SenElection *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.66071 	 	    0.66071
# mean control..........    0.59259 	 	      0.625
# std mean diff.........     14.259 	 	     7.4755
#
# mean raw eQQ diff.....   0.074074 	 	   0.035714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.034061 	 	   0.017857
# med  eCDF diff........   0.034061 	 	   0.017857
# max  eCDF diff........   0.068122 	 	   0.035714
#
# var ratio (Tr/Co).....    0.91039 	 	    0.95646
# T-test p-value........    0.55833 	 	    0.48053
#
#
# ***** (V5) factor(fips_state)5 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V6) factor(fips_state)12 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.071429 	 	   0.071429
# mean control..........          0 	 	          0
# std mean diff.........     27.486 	 	     27.486
#
# mean raw eQQ diff.....   0.074074 	 	   0.071429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.035714 	 	   0.035714
# med  eCDF diff........   0.035714 	 	   0.035714
# max  eCDF diff........   0.071429 	 	   0.071429
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.044453 	 	    0.04263
#
#
# ***** (V7) factor(fips_state)13 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V8) factor(fips_state)16 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.074074 	 	       0.25
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.074074 	 	       0.25
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.037037 	 	      0.125
# med  eCDF diff........   0.037037 	 	      0.125
# max  eCDF diff........   0.074074 	 	       0.25
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16118 	 	 6.5726e-05
#
#
# ***** (V9) factor(fips_state)17 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V10) factor(fips_state)19 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.14815 	 	    0.21429
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.14815 	 	    0.21429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.074074 	 	    0.10714
# med  eCDF diff........   0.074074 	 	    0.10714
# max  eCDF diff........    0.14815 	 	    0.21429
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.043123 	 	 0.00025728
#
#
# ***** (V11) factor(fips_state)23 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.074074 	 	   0.071429
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.074074 	 	   0.071429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.037037 	 	   0.035714
# med  eCDF diff........   0.037037 	 	   0.035714
# max  eCDF diff........   0.074074 	 	   0.071429
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16118 	 	    0.04263
#
#
# ***** (V12) factor(fips_state)24 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V13) factor(fips_state)26 *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.071429 	 	   0.071429
# mean control..........          0 	 	          0
# std mean diff.........     27.486 	 	     27.486
#
# mean raw eQQ diff.....   0.074074 	 	   0.071429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.035714 	 	   0.035714
# med  eCDF diff........   0.035714 	 	   0.035714
# max  eCDF diff........   0.071429 	 	   0.071429
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.044453 	 	    0.04263
#
#
# ***** (V14) factor(fips_state)27 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.074074 	 	   0.053571
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.074074 	 	   0.053571
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.037037 	 	   0.026786
# med  eCDF diff........   0.037037 	 	   0.026786
# max  eCDF diff........   0.074074 	 	   0.053571
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16118 	 	   0.080535
#
#
# ***** (V15) factor(fips_state)33 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.14815 	 	   0.089286
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.14815 	 	   0.089286
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.074074 	 	   0.044643
# med  eCDF diff........   0.074074 	 	   0.044643
# max  eCDF diff........    0.14815 	 	   0.089286
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.043123 	 	   0.022767
#
#
# ***** (V16) factor(fips_state)35 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.074074 	 	   0.017857
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.074074 	 	   0.017857
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.037037 	 	  0.0089286
# med  eCDF diff........   0.037037 	 	  0.0089286
# max  eCDF diff........   0.074074 	 	   0.017857
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16118 	 	    0.31737
#
#
# ***** (V17) factor(fips_state)36 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V18) factor(fips_state)41 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.22222 	 	    0.21429
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.22222 	 	    0.21429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.11111 	 	    0.10714
# med  eCDF diff........    0.11111 	 	    0.10714
# max  eCDF diff........    0.22222 	 	    0.21429
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.011333 	 	 0.00025728
#
#
# ***** (V19) factor(fips_state)45 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V20) factor(fips_state)47 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10714 	 	    0.10714
# mean control..........          0 	 	          0
# std mean diff.........      34.33 	 	      34.33
#
# mean raw eQQ diff.....    0.11111 	 	    0.10714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.053571 	 	   0.053571
# med  eCDF diff........   0.053571 	 	   0.053571
# max  eCDF diff........    0.10714 	 	    0.10714
#
# var ratio (Tr/Co).....        Inf 	 	        Inf
# T-test p-value........   0.012941 	 	   0.012188
#
#
# ***** (V21) factor(fips_state)50 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........   0.074074 	 	   0.017857
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....   0.074074 	 	   0.017857
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.037037 	 	  0.0089286
# med  eCDF diff........   0.037037 	 	  0.0089286
# max  eCDF diff........   0.074074 	 	   0.017857
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........    0.16118 	 	    0.31737
#
#
# ***** (V22) factor(fips_state)56 *****
#                        Before Matching 	 	 After Matching
# mean treatment........          0 	 	          0
# mean control..........    0.11111 	 	   0.071429
# std mean diff.........       -Inf 	 	       -Inf
#
# mean raw eQQ diff.....    0.11111 	 	   0.071429
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.055556 	 	   0.035714
# med  eCDF diff........   0.055556 	 	   0.035714
# max  eCDF diff........    0.11111 	 	   0.071429
#
# var ratio (Tr/Co).....          0 	 	          0
# T-test p-value........   0.083027 	 	    0.04263
#
#
# ***** (V23) factor(year)1990 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16071 	 	    0.16071
# mean control..........     0.2963 	 	       0.25
# std mean diff.........    -36.585 	 	    -24.093
#
# mean raw eQQ diff.....    0.14815 	 	   0.089286
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.067791 	 	   0.044643
# med  eCDF diff........   0.067791 	 	   0.044643
# max  eCDF diff........    0.13558 	 	   0.089286
#
# var ratio (Tr/Co).....    0.63428 	 	    0.71939
# T-test p-value........    0.19228 	 	    0.12951
#
#
# ***** (V24) factor(year)1994 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16071 	 	    0.16071
# mean control..........    0.11111 	 	    0.10714
# std mean diff.........     13.385 	 	     14.456
#
# mean raw eQQ diff.....   0.037037 	 	   0.053571
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024802 	 	   0.026786
# med  eCDF diff........   0.024802 	 	   0.026786
# max  eCDF diff........   0.049603 	 	   0.053571
#
# var ratio (Tr/Co).....      1.339 	 	       1.41
# T-test p-value........    0.53284 	 	    0.36616
#
#
# ***** (V25) factor(year)1998 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16071 	 	    0.16071
# mean control..........   0.074074 	 	    0.17857
# std mean diff.........     23.379 	 	    -4.8186
#
# mean raw eQQ diff.....   0.074074 	 	   0.017857
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.04332 	 	  0.0089286
# med  eCDF diff........    0.04332 	 	  0.0089286
# max  eCDF diff........    0.08664 	 	   0.017857
#
# var ratio (Tr/Co).....     1.9282 	 	    0.91957
# T-test p-value........    0.22877 	 	    0.76398
#
#
# ***** (V26) factor(year)2002 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17857 	 	    0.17857
# mean control..........   0.037037 	 	   0.053571
# std mean diff.........     36.623 	 	     32.345
#
# mean raw eQQ diff.....    0.14815 	 	      0.125
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.070767 	 	     0.0625
# med  eCDF diff........   0.070767 	 	     0.0625
# max  eCDF diff........    0.14153 	 	      0.125
#
# var ratio (Tr/Co).....     4.0325 	 	     2.8931
# T-test p-value........    0.02872 	 	   0.049315
#
#
# ***** (V27) factor(year)2006 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17857 	 	    0.17857
# mean control..........    0.14815 	 	    0.21429
# std mean diff.........     7.8723 	 	    -9.2414
#
# mean raw eQQ diff.....   0.037037 	 	   0.035714
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.015212 	 	   0.017857
# med  eCDF diff........   0.015212 	 	   0.017857
# max  eCDF diff........   0.030423 	 	   0.035714
#
# var ratio (Tr/Co).....     1.1396 	 	    0.87121
# T-test p-value........    0.72708 	 	    0.31737
#
#
# Before Matching Minimum p.value: 0.011333
# Variable Name(s): factor(fips_state)41  Number(s): 18
#
# After Matching Minimum p.value: 6.5726e-05
# Variable Name(s): factor(fips_state)16  Number(s): 8

# %% [markdown]
# wait why did my balance become worseeeee
