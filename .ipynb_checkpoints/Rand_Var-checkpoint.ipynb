# %% [markdown]
# Describes how extracurricular engagement (percentile of student on attendence of optional school activities) is affected by both student diligence and family income. While student diligence could increase the amount of optional school activities attended, family income is very likely a limiting factor. students with more financial restrictions would have priorities above optional school activities.

# %%
dilligence <- rnorm(200,1,10) 
family_income <- rnbinom(200,10,.5)

academic_engagement <- 50 + 10*dilligence + (500*family_income) + rnorm(200,0,1000)

# %%
hist(dilligence)
# Out:
# Plot with title “Histogram of dilligence”

# %%
hist(family_income)
# Out:
# Plot with title “Histogram of family_income”

# %%
hist(academic_engagement)
# Out:
# Plot with title “Histogram of academic_engagement”

# %%
# see results
lm(academic_engagement ~ dilligence + family_income)
# Out:
# Call:
# lm(formula = academic_engagement ~ dilligence + family_income)
#
# Coefficients:
#   (Intercept)     dilligence  family_income
#       237.335         -1.861        486.409

# %%
minervans <- ceiling(runif(200,0,7))
floor <- ceiling (runif(200,0,5))

print(minervans)
# Out:
#   [1] 5 2 5 3 1 5 7 1 2 5 2 7 2 3 7 4 4 1 5 2 4 3 7 5 5 2 3 7 6 4 2 6 1 3 2 4 6
#  [38] 7 2 7 1 5 3 6 6 7 3 6 6 7 6 5 4 2 4 7 7 5 4 2 5 1 5 5 2 5 7 2 6 2 2 1 4 4
#  [75] 6 4 7 1 2 2 3 2 2 5 7 3 1 2 5 4 4 1 6 2 3 2 7 2 1 6 6 1 3 5 1 5 3 2 2 2 2
# [112] 2 5 2 1 2 4 5 5 4 5 6 3 1 1 7 4 3 3 6 4 7 1 5 6 1 3 2 5 1 6 5 6 4 2 6 1 2
# [149] 7 4 3 3 4 1 6 2 5 5 7 2 2 5 7 6 5 5 6 1 1 4 7 1 5 5 2 3 4 1 3 7 1 2 6 6 4
# [186] 5 6 7 4 3 6 7 5 7 5 1 5 2 4 4

# %%
print(floor)
# Out:
#   [1] 4 1 3 5 5 2 4 5 2 5 4 4 1 1 3 4 3 5 5 3 1 2 3 5 4 1 4 3 4 5 1 3 4 1 3 1 4
#  [38] 4 5 2 3 4 3 4 4 2 1 2 3 2 3 1 4 5 1 3 4 1 4 4 4 1 2 4 5 5 5 4 2 5 2 5 2 4
#  [75] 5 2 4 1 3 4 3 4 5 1 5 5 2 5 4 1 3 2 5 1 3 4 4 2 2 3 2 1 1 3 1 2 5 2 4 2 3
# [112] 5 2 3 3 3 3 1 3 5 2 4 5 1 1 5 2 1 4 5 1 2 2 3 2 4 3 1 3 2 3 4 4 5 2 1 2 4
# [149] 1 4 2 1 1 3 5 3 5 4 2 5 5 3 3 3 1 2 1 1 5 1 3 3 1 2 1 3 3 2 1 2 5 1 5 5 2
# [186] 4 2 5 5 2 2 1 2 2 3 3 2 1 1 3

# %%
quality = 10*minervans + 5*floor + rnorm(200,0,10)

print(quality)
# Out:
#   [1]  18.283558  75.874745  86.307351  80.568453  83.688992  46.244718
#   [7]  81.526131  70.184095  18.973139  65.017532  60.074769  78.791613
#  [13]  73.497941   6.490661  52.747286  43.921714  75.275237  49.755150
#  [19]  33.633744  59.010567  59.017102  20.584420  34.660447  37.962655
#  [25]  70.517412  84.758834  34.162547  75.844396  52.798916  82.170502
#  [31]  68.793050  52.739744  47.370003  46.617826  91.774981  42.015136
#  [37]  47.310986  57.323533  79.928022  82.825275  44.030427  45.609745
#  [43]  86.937007  19.293154  88.911858  66.781397  64.921215  50.409102
#  [49]  38.862026  73.746391  50.678576  55.759390  75.903252  35.309199
#  [55]  80.138515  45.942243  67.141193  36.031793  40.894761  67.245272
#  [61]  41.420989  26.751903  51.938834 118.740009  84.502001  89.822966
#  [67]  76.644560  70.684759  66.512873 103.215429  53.670023  44.540641
#  [73]  83.033846  44.283477  22.830012  28.265652  61.070719  40.874086
# ...
