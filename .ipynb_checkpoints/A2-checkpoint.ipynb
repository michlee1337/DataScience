# %% [markdown]
# # Generate Data

# %%
x = rnorm(999,0,10)
y = 2*x + rnorm(999,0,10)
data = data.frame(x,y)

plot(data$x,data$y)
fit1 = lm(y ~ x)
abline(fit1)
# Out:
# plot without title

# %%
data = rbind(data,c(3000,-4000))
plot(data$x,data$y)
fit2 = lm(data$x ~ data$y)
abline(fit2)
# Out:
# plot without title

# %%
summary(fit1)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -26.3708  -6.5308  -0.4293   6.2229  30.7570
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.17426    0.31051  -0.561    0.575
# x            1.94097    0.03103  62.555   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.814 on 997 degrees of freedom
# Multiple R-squared:  0.797,	Adjusted R-squared:  0.7967
# F-statistic:  3913 on 1 and 997 DF,  p-value: < 2.2e-16

# %%
summary(fit2)
# Out:
# Call:
# lm(formula = data$x ~ data$y)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -74.092 -17.335  -0.816  16.720 133.272
#
# Coefficients:
#              Estimate Std. Error  t value Pr(>|t|)
# (Intercept)  0.180862   0.800570    0.226    0.821
# data$y      -0.716637   0.006238 -114.891   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 25.3 on 998 degrees of freedom
# Multiple R-squared:  0.9297,	Adjusted R-squared:  0.9296
# F-statistic: 1.32e+04 on 1 and 998 DF,  p-value: < 2.2e-16
