# %% [markdown]
# # Question 1

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
def f1(x,y):
    return(x+y)

def f2(x,y):
    return(x**2+4*y**2)

def f3(x,y):
    return(x*y)

def f4(x,y):
    return(x**2-y**2)

def f5(x,y):
    return(x**2+2*x*y+y**2)

def f6(x,y):
    return(x**4+2*x*y+y**4)

# %%
x = np.linspace(-50, 50, 30)
y = np.linspace(-50, 50, 30)

X, Y = np.meshgrid(x, y)

# %%
Z1 = f1(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z1, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z1)

# %%
Z2 = f2(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z2, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z2)

# %%
Z3 = f3(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z3, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z3)

# %%
Z4 = f4(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z4, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z4)

# %%
Z5 = f5(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z5, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z5)

# %%
Z6 = f6(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour(X, Y, Z6, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()
plt.contour(X, Y, Z6)

# %% [markdown]
# Only 2 and 4 are coercive

# %% [markdown]
# # Question 2

# %% [markdown]
# It is coercive because as x, y, or z tends to infinity, f(x,y,z) increases without bound (tends to infinity)

# %% [markdown]
# $\forall M > 0, \exists \delta > 0$ such that $f(x) > M \forall x$
#
# $f(x,y,z) > M$
#
# $M > e^{x^2+y^2+z^2}$
#
#
# $ln(M) > x^2+y^2+z^2$
#
#
# $ln(M) > 0$ since squares are always positive
#
#
# $\sqrt(ln(M)) > \sqrt{(x^2+y^2+z^2)}$
#
#
# $\forall M > 0, \exists \delta = \sqrt{(ln(M))}$ where $L > 0$ such that when $\sqrt(x^2+y^2+z^2) > \delta, f(x,y,z) > M$
#
# Thus, the function is coercive as it grows without bounds.

# %% [markdown]
# The sublevel sets are
# $L_f(\alpha) = {x\in R^n, y \in R^n, z \in R^n:f(x,y,z) <\ \alpha}$

# %%
def fL(x,y):
    return(100*x**(3/4)*y**(1/4))

def gL(x,y):
    return(200*x+250*y-50000)
x = np.linspace(-50, 50, 30)
y = np.linspace(-50, 50, 30)

X, Y = np.meshgrid(x, y)

Z1 = fL(X, Y)
Z2 = gL(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z1, 50, cmap='binary')
ax.contour3D(X, Y, Z2, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

plt.contour(X, Y, Z1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in power
